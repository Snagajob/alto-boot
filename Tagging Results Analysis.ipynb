# %%
import os
logs_dir = "data/large_sample_20/log/"
users = list({x.split("_")[0] for x in os.listdir(logs_dir)})
users
# Out:
# ['Aash', 'ghost-rider', 'chrislin', 'johnmoon']

# %%
def parse_logfile_name(logfile_name):
    out = dict()
    out["filename"] = logfile_name
    d = logfile_name[0:-4].split("_")
    out["user"] = d[0]
    if d[1] == "log":
        out["date"] = d[3]
        out["time"] = d[4]
        out["n"] = d[2]
        out["label_file"] = False
    else:
        out["date"] = d[1]
        out["time"] = d[2]
        out["label_file"] = True
        out["update"] = len(d)==4
    return out


    
def get_last_update(logs_dir, user):
    user_files = [parse_logfile_name(x)
                  for x in os.listdir(logs_dir)
                  if x.find(user) >= 0]
    label_files = [f for f in user_files if f["label_file"]]
    label_files = sorted(label_files, key=lambda x: x["time"])
    last_file = label_files[-1]
    last_non_update = [f for f in label_files if not f["update"]][-1]
    return [last_file, last_non_update]
    
    
user_files = {user:get_last_update(logs_dir, user) for user in users}
    
user_files
# Out:
# {'Aash': [{'date': '20171006',
#    'filename': 'Aash_20171006_170734_update.log',
#    'label_file': True,
#    'time': '170734',
#    'update': True,
#    'user': 'Aash'},
#   {'date': '20171006',
#    'filename': 'Aash_20171006_170208.log',
#    'label_file': True,
#    'time': '170208',
#    'update': False,
#    'user': 'Aash'}],
#  'chrislin': [{'date': '20171006',
#    'filename': 'chrislin_20171006_170653_update.log',
#    'label_file': True,
#    'time': '170653',
#    'update': True,
#    'user': 'chrislin'},
#   {'date': '20171006',
#    'filename': 'chrislin_20171006_170628.log',
#    'label_file': True,
#    'time': '170628',
#    'update': False,
#    'user': 'chrislin'}],
#  'ghost-rider': [{'date': '20171006',
#    'filename': 'ghost-rider_20171006_170659_update.log',
#    'label_file': True,
#    'time': '170659',
#    'update': True,
#    'user': 'ghost-rider'},
#   {'date': '20171006',
#    'filename': 'ghost-rider_20171006_170640.log',
#    'label_file': True,
#    'time': '170640',
#    'update': False,
#    'user': 'ghost-rider'}],
#  'johnmoon': [{'date': '20171006',
#    'filename': 'johnmoon_20171006_170653_update.log',
#    'label_file': True,
#    'time': '170653',
#    'update': True,
#    'user': 'johnmoon'},
#   {'date': '20171006',
#    'filename': 'johnmoon_20171006_170503.log',
#    'label_file': True,
#    'time': '170503',
#    'update': False,
#    'user': 'johnmoon'}]}

# %%
from collections import defaultdict

def parse_label_file(log_dir, filename):
    headers = ["TOP IDS:", "User labels:", "Classification results:", "All classification results:", ""]
    out = defaultdict(lambda: [])
    with open(log_dir + "/" + filename) as f:
        header_n = -1
        for i in range(8):
            out["header"].append(f.readline())
        for l in f:
            if l.strip() == headers[header_n+1]:
                header_n = header_n + 1
            if l.strip() not in headers:
                out[headers[header_n]].append(l)
    out["Classification results:"] = [parse_classification_result(r)
                                    for r in out["Classification results:"]]
    out["User labels:"] = [parse_user_label(r)
                                    for r in out["User labels:"]]
    out = {k:v for k,v in out.items()}
    return out
                

def parse_classification_result(r):
    out = dict()
    d = r.strip().split(",")
    out["posting_id"], out["label"] = d[0].split(":")
    out["score"] = float(d[1])
    return out

    
def parse_user_label(r):
    out = dict()
    out["posting_id"], out["label"] = r.strip().split(":")
    return out
    

user_labels = {user:parse_label_file(logs_dir, user_files[user][0]["filename"]) for user in users}
user_labels
# Out:
# {'Aash': {'All classification results:': ['40833549:human care services,0.2565450826852724\n',
#    '37958013:event services,0.9869487118879179\n',
#    '37903780:technical services,0.29127736635346496\n',
#    '29972102:human care services,0.29700523083494307\n',
#    '42063689:human care services,0.7543314775465478\n',
#    '39398891:human care services,0.3818699044058074\n',
#    '43744307:hotel and hospitality,0.9982499111255706\n',
#    '41734445:it or software services,0.21377643936777876\n',
#    '22792419:it or software services,0.21646262356102156\n',
#    '37903788:technical services,0.3227724316836302\n',
#    '39263940:human care services,0.3026198072856141\n',
#    '37901118:technical services,0.302191234998833\n',
#    '35474928:human care services,0.41487047964346535\n',
#    '37834682:food and beverage,0.269723621849499\n',
#    '42635340:human care services,0.8687087867450027\n',
#    '41811171:human care services,0.3226214451783049\n',
#    '42406321:technical services,0.3174789987773842\n',
#    '35814531:it or software services,0.16201381382332677\n',
#    '40493930:it or software services,0.19374182099807818\n',
#    '33827309:technical services,0.32935749602846054\n',
#    '28478953:human care services,0.2007380256143093\n',
#    '35388472:human care services,0.4337543512033164\n',
#    '44130681:it or software services,0.18999904437655377\n',
#    '34156555:food and beverage,0.18902912889749907\n',
#    '41868057:human care services,0.5249212479332801\n',
#    '43655602:it or software services,0.3629412945578174\n',
#    '44496330:human care services,0.8791675486070305\n',
#    '37401619:it or software services,0.3934479760415143\n',
#    '35855080:it or software services,0.28797003850746716\n',
#    '40284524:human care services,0.7775543900729183\n',
#    '34857827:human care services,0.2935784325650304\n',
#    '35999751:technical services,0.46094077580936027\n',
#    '34083060:it or software services,0.29249612794464647\n',
#    '34083062:it or software services,0.2851032269000682\n',
#    '42461190:administrative services,0.3229916971551053\n',
#    '35192053:human care services,0.508299757307349\n',
#    '43792857:human care services,0.3771375083694633\n',
#    '29494843:human care services,0.1975394374070292\n',
#    '30517739:it or software services,0.2281924915061155\n',
#    '43789216:technical services,0.48599035030249466\n',
#    '30517732:it or software services,0.20833204005543607\n',
#    '44300494:technical services,0.3667689713930948\n',
#    '44472377:it or software services,0.9991048935934406\n',
#    '26810996:human care services,0.2475778225433908\n',
#    '36019830:human care services,0.5388064182007845\n',
#    '43693093:administrative services,0.2242853890093127\n',
#    '43693092:human care services,0.283398009245676\n',
#    '43811693:it or software services,0.2752649597130515\n',
#    '42856704:human care services,0.27002734010022267\n',
#    '26544472:human care services,0.43859280289751573\n',
#    '38073865:it or software services,0.26394435888987666\n',
#    '34259879:human care services,0.29265574568791336\n',
#    '37159987:human care services,0.3691388243870849\n',
#    '36443608:it or software services,0.41188622888519616\n',
#    '26789863:human care services,0.2635776954696239\n',
#    '37550849:transportation services,0.24873238133423894\n',
#    '39259892:human care services,0.2953323751469384\n',
#    '42580513:hotel and hospitality,0.9976537491388529\n',
#    '36014137:technical services,0.43654797148427965\n',
#    '44247708:it or software services,0.20537868392397457\n',
#    '42843420:hotel and hospitality,0.7458282871606083\n',
#    '43754561:it or software services,0.25840225102021047\n',
#    '39398861:human care services,0.347833961631392\n',
#    '37032694:administrative services,0.31471103622108565\n',
#    '29728385:human care services,0.20721807314728785\n',
#    '38278311:education,0.7711187407114685\n',
#    '33968963:it or software services,0.44164029936438837\n',
#    '33869167:human care services,0.32285345002691096\n',
#    '39398862:human care services,0.2743672259649926\n',
#    '37903776:technical services,0.2728769406714864\n',
#    '40209289:human care services,0.2036453584269649\n',
#    '35677633:hotel and hospitality,0.999130495971892\n',
#    '43927434:human care services,0.2663287832104089\n',
#    '30651014:it or software services,0.20387151456073818\n',
#    '34185080:it or software services,0.18273799858620704\n',
#    '37210084:administrative services,0.1976955100299936\n',
#    '43961310:it or software services,0.2021701216918826\n',
#    '42352859:it or software services,0.2563957260690423\n',
#    '43169003:human care services,0.6514257374413325\n',
#    '37860935:it or software services,0.22008060549898872\n',
#    '43971588:it or software services,0.2171678592633963\n',
#    '42613989:food and beverage,0.19027471062241794\n',
#    '44430533:human care services,0.5542924850319252\n',
#    '39266176:human care services,0.6635182904122935\n',
#    '29113514:human care services,0.15706166927126736\n',
#    '29113517:it or software services,0.19138817764611613\n',
#    '35352486:automotive services,0.946733603457444\n',
#    '38692719:human care services,0.6293449929515631\n',
#    '44425189:human care services,0.5356349746189355\n',
#    '32754863:technical services,0.475991525464774\n',
#    '31004739:it or software services,0.20832893534176403\n',
#    '39640526:human care services,0.18498809007214437\n',
#    '26773470:it or software services,0.34647569532634426\n',
#    '35904536:technical services,0.42213916057481826\n',
#    '43693067:human care services,0.283398009245676\n',
#    '42062307:human care services,0.24660612933827059\n',
#    '42293122:hotel and hospitality,0.8736771611763139\n',
#    '33655744:human care services,0.8910972951840687\n',
#    '42340814:human care services,0.613467478403975\n',
#    '30020100:human care services,0.6439940424182748\n',
#    '42592556:human care services,0.21056379420145718\n',
#    '44430522:human care services,0.9277333567945137\n',
#    '34935868:human care services,0.6582234368171693\n',
#    '40464576:it or software services,0.18207453584279296\n',
#    '41543732:administrative services,0.19118094306620173\n',
#    '42470099:it or software services,0.38061688319976306\n',
#    '43647167:technical services,0.4884813757588309\n',
#    '41901189:human care services,0.20555889165002403\n',
#    '44139068:human care services,0.7469521411238407\n',
#    '42593870:human care services,0.19109113505813663\n',
#    '44431884:human care services,0.6117791421717492\n',
#    '43350066:administrative services,0.2868096521927193\n',
#    '43268822:human care services,0.30370998720176606\n',
#    '34009967:human care services,0.158234342097539\n',
#    '43534471:it or software services,0.48997675950696257\n',
#    '42929379:it or software services,0.31703678832162696\n',
#    '40209252:human care services,0.19196502896117837\n',
#    '44039656:human care services,0.3241971808677973\n',
#    '44358680:it or software services,0.32442923833766985\n',
#    '41901159:human care services,0.25392756191644705\n',
#    '25874325:human care services,0.26219205492325937\n',
#    '37591344:it or software services,0.22080428100402094\n',
#    '26544428:human care services,0.30171231930852277\n',
#    '41901155:human care services,0.23619415047364845\n',
#    '42245401:human care services,0.7061297070525898\n',
#    '44145747:human care services,0.7854944617240737\n',
#    '44026353:it or software services,0.21994505229425143\n',
#    '38598622:it or software services,0.21506018453339573\n',
#    '34107540:it or software services,0.19225201851838167\n',
#    '44026358:human care services,0.4200184979959946\n',
#    '38015926:event services,0.9943005231527329\n',
#    '38598620:it or software services,0.20838621778367442\n',
#    '39080872:human care services,0.1859484276114414\n',
#    '40559425:technical services,0.6433368996505474\n',
#    '35860476:human care services,0.21858813018728773\n',
#    '34287941:human care services,0.5944517547278579\n',
#    '38792158:human care services,0.49380388778584844\n',
#    '43202129:it or software services,0.2334224563570529\n',
#    '44220682:human care services,0.5357971073693601\n',
#    '26579180:it or software services,0.18630784010731846\n',
#    '38723516:it or software services,0.25417330388382087\n',
#    '43534462:it or software services,0.3596929977928621\n',
#    '43172684:human care services,0.5776584383613721\n',
#    '43787499:technical services,0.5101202130944708\n',
#    '44349748:technical services,0.42643600390974856\n',
#    '42929382:it or software services,0.23554964798585418\n',
#    '27550185:human care services,0.18687164723673977\n',
#    '36092499:human care services,0.48362242176380343\n',
#    '44138558:human care services,0.733051720855463\n',
#    '43166817:human care services,0.7241813406966618\n',
#    '43350004:administrative services,0.289314929923945\n',
#    '41024271:technical services,0.4897612723754692\n',
#    '43352664:it or software services,0.37836116480869014\n',
#    '43780009:human care services,0.3786970200444285\n',
#    '38277058:event services,0.9991154189032786\n',
#    '39082607:human care services,0.18620835689863297\n',
#    '44057467:human care services,0.3513434716645606\n',
#    '36049621:administrative services,0.18746848245332545\n',
#    '43790295:technical services,0.3217742922198971\n',
#    '30604657:human care services,0.21101850724952928\n',
#    '30604656:human care services,0.19526134464288475\n',
#    '36273867:technical services,0.5298950516952512\n',
#    '37900667:technical services,0.3379347577363605\n',
#    '43281814:human care services,0.8394341678964203\n',
#    '26741828:human care services,0.38752783285947995\n',
#    '38191072:education,0.830170189187483\n',
#    '44205916:human care services,0.27088044347124457\n',
#    '25793297:human care services,0.1934027720533779\n',
#    '30585013:it or software services,0.19423333521483907\n',
#    '35474091:it or software services,0.2962919108835168\n',
#    '43486299:administrative services,0.1725675362376895\n',
#    '34861016:human care services,0.8923407351767652\n',
#    '36726962:human care services,0.486162900742806\n',
#    '38196764:it or software services,0.1480648563647453\n',
#    '36095538:human care services,0.5529136117218124\n',
#    '41385977:human care services,0.2308544455448141\n',
#    '39080898:human care services,0.20425360681239527\n',
#    '33928881:human care services,0.4005266103835005\n',
#    '35352454:human care services,0.17802976281775276\n',
#    '39027788:it or software services,0.16873694123718813\n',
#    '44488785:it or software services,0.2722547834047147\n',
#    '38502109:it or software services,0.28408622546178114\n',
#    '36677446:human care services,0.18130267490606394\n',
#    '43933287:human care services,0.9114099237194334\n',
#    '35681757:human care services,0.6447154521691517\n',
#    '30604647:human care services,0.19583379954448638\n',
#    '39153432:human care services,0.7909124498356331\n',
#    '36677447:automotive services,0.9981637019733826\n',
#    '42705702:human care services,0.44325279087727626\n',
#    '26741831:human care services,0.37055038160038795\n',
#    '38841685:human care services,0.17906065745550998\n',
#    '39082624:human care services,0.16429921712272855\n',
#    '41757180:human care services,0.6321416089090033\n',
#    '42063625:human care services,0.7714938084177919\n',
#    '43580371:human care services,0.2237896934985288\n',
#    '43580370:human care services,0.18746338950306665\n',
#    '29969355:it or software services,0.18801351861632878\n',
#    '36677485:human care services,0.19452690519838348\n',
#    '34727719:human care services,0.2996161071788824\n',
#    '35714300:technical services,0.3293387982228956\n',
#    '36712326:it or software services,0.21645316936586156\n',
#    '44422968:human care services,0.6054400984568269\n',
#    '30604637:human care services,0.20962774070551562\n',
#    '36004734:technical services,0.3638879217578661\n',
#    '43580362:it or software services,0.24065510445947805\n',
#    '44205937:human care services,0.2752198506621306\n',
#    '36013689:technical services,0.41547921422336354\n',
#    '34387319:it or software services,0.29082811908814304\n',
#    '39361542:it or software services,0.23399042604198952\n',
#    '39402615:human care services,0.2843244221297735\n',
#    '44197742:it or software services,0.24544603123121084\n',
#    '35384057:human care services,0.3018750179668267\n',
#    '38196787:human care services,0.18446772856871022\n',
#    '35812731:technical services,0.6532060628220459\n',
#    '42366609:technical services,0.5243510565409253\n',
#    '35864874:technical services,0.39934842811863935\n',
#    '41402933:food and beverage,0.7601629624147563\n',
#    '39082612:human care services,0.20880248604153276\n',
#    '38277066:event services,0.9978530991115779\n',
#    '42646860:it or software services,0.4084595488256686\n',
#    '43080044:it or software services,0.3388244336213392\n',
#    '27550159:it or software services,0.22318894540273465\n',
#    '37641325:it or software services,0.4237697272057921\n',
#    '33969416:technical services,0.436049797173554\n',
#    '33559007:technical services,0.8072157556975247\n',
#    '41091081:it or software services,0.2348968631124082\n',
#    '44381090:hotel and hospitality,0.9988342414406681\n',
#    '29969358:human care services,0.170101168980522\n',
#    '43136184:it or software services,0.2627386769959719\n',
#    '36013696:technical services,0.44025591353786303\n',
#    '35213435:administrative services,0.21404900580403122\n',
#    '35352402:it or software services,0.18274338843811921\n',
#    '41214438:it or software services,0.47337758705696564\n',
#    '36534092:human care services,0.5383528889766965\n',
#    '43560779:human care services,0.38488465831937574\n',
#    '41703344:hotel and hospitality,0.7279793221860602\n',
#    '34337043:technical services,0.2779891664117896\n',
#    '43139240:it or software services,0.2554329226511431\n',
#    '40082258:human care services,0.24059842531971126\n',
#    '40697164:food and beverage,0.1837948974356819\n',
#    '29491780:human care services,0.6887866050838097\n',
#    '38199832:technical services,0.23064639363463932\n',
#    '42999251:human care services,0.18743479846697497\n',
#    '43411516:it or software services,0.9997023090886297\n',
#    '39081309:human care services,0.17751120255851238\n',
#    '42866985:human care services,0.23071688550972824\n',
#    '43812911:it or software services,0.34677008444279395\n',
#    '38279660:education,0.7660296985607444\n',
#    '43089285:it or software services,0.5574953764666667\n',
#    '38013364:event services,0.9978665953186755\n',
#    '44381022:hotel and hospitality,0.9987067619733447\n',
#    '26335947:it or software services,0.3762354769206941\n',
#    '38514129:it or software services,0.43437426381991284\n',
#    '29993868:it or software services,0.25995949524401407\n',
#    '43530954:hotel and hospitality,0.9992475499573157\n',
#    '32994538:human care services,0.2823991684560981\n',
#    '43121953:administrative services,0.15888272671470227\n',
#    '43281868:it or software services,0.24345353818846144\n',
#    '35728949:human care services,0.5288850383660835\n',
#    '37091046:technical services,0.2873731428575453\n',
#    '33928816:human care services,0.6081297774917325\n',
#    '37644409:administrative services,0.219634750395181\n',
#    '40116188:it or software services,0.27611059316192527\n',
#    '37140498:it or software services,0.29998520313512667\n',
#    '43423527:technical services,0.500535966825594\n',
#    '44372108:human care services,0.2637071210698692\n',
#    '44057494:human care services,0.6962568067697439\n',
#    '36677439:automotive services,0.9979233702922792\n',
#    '36677436:human care services,0.18702671547182723\n',
#    '34001173:human care services,0.21104908896193175\n',
#    '43930186:human care services,0.7961782980284026\n',
#    '37160092:human care services,0.5161558628181483\n',
#    '43743086:human care services,0.21325581717054845\n',
#    '44129695:administrative services,0.3336374463908505\n',
#    '34595448:food and beverage,0.1952302885573098\n',
#    '43465357:human care services,0.6289396250269697\n',
#    '33620264:it or software services,0.46285121318034517\n',
#    '35714327:technical services,0.7148387289694682\n',
#    '35005400:it or software services,0.35236466314706777\n',
#    '37235311:technical services,0.440275489168049\n',
#    '36799091:technical services,0.3636933103333727\n',
#    '38971702:human care services,0.27782246666820404\n',
#    '43364610:it or software services,0.24638287209168114\n',
#    '44339549:human care services,0.8112073828933472\n',
#    '36677424:automotive services,0.9981146206772685\n',
#    '36677422:it or software services,0.18241257650117546\n',
#    '43504676:human care services,0.5268741653275074\n',
#    '36677427:automotive services,0.9482301881018693\n',
#    '42688786:human care services,0.7909069987792675\n',
#    '44434991:human care services,0.7355611760536744\n',
#    '37308855:human care services,0.40288867141423684\n',
#    '33657513:human care services,0.7623707327097838\n',
#    '30337671:human care services,0.2150091629027891\n',
#    '39081237:human care services,0.18218194749965708\n',
#    '38298830:event services,0.9903054606151006\n',
#    '29165557:it or software services,0.2641736803195628\n',
#    '41300083:human care services,0.19652151448870564\n',
#    '44057506:human care services,0.24737370582976226\n',
#    '42800363:it or software services,0.29095947167534164\n',
#    '40289426:it or software services,0.4799186710706324\n',
#    '40543844:administrative services,0.19425918560622332\n',
#    '38317561:technical services,0.2728083515238589\n',
#    '43278256:human care services,0.21937648622339004\n',
#    '44502792:food and beverage,0.2415697859727577\n',
#    '37504171:technical services,0.3229482013316431\n',
#    '39747406:human care services,0.20421296882588433\n',
#    '35866653:technical services,0.3591134037871729\n',
#    '40381662:human care services,0.6989138972104597\n',
#    '42408069:it or software services,0.31811697390038735\n',
#    '39255511:human care services,0.2846463878853471\n',
#    '29978330:human care services,0.6997312650519786\n',
#    '40609303:human care services,0.19386931527870044\n',
#    '43564397:administrative services,0.25318693143825427\n',
#    '37910865:education,0.8936073996901523\n',
#    '34514028:it or software services,0.31605430959664443\n',
#    '36021202:it or software services,0.1663811347335932\n',
#    '35865304:technical services,0.2245434758380338\n',
#    '38693180:human care services,0.3367735971793833\n',
#    '26441918:human care services,0.7560035492973273\n',
#    '40933844:human care services,0.19575541349325112\n',
#    '43338405:human care services,0.7052926230747809\n',
#    '38317567:event services,0.9895790224611163\n',
#    '40818725:human care services,0.1961617391142073\n',
#    '36992075:it or software services,0.4049212436264967\n',
#    '40818720:it or software services,0.22090716688933168\n',
#    '29620263:human care services,0.29603332442948316\n',
#    '40321147:human care services,0.9918832791956282\n',
#    '31836627:human care services,0.23720228740994428\n',
#    '36738094:it or software services,0.18224923765727088\n',
#    '34218579:it or software services,0.16973956932247855\n',
#    '38274882:education,0.9268289967239227\n',
#    '26369313:human care services,0.21198313730058166\n',
#    '37087811:technical services,0.3132512791297364\n',
#    '34872537:human care services,0.2489545548993558\n',
#    '33439151:it or software services,0.2065474808129132\n',
#    '36518818:technical services,0.3945723342704956\n',
#    '44110129:human care services,0.32732732250667124\n',
#    '34578810:human care services,0.3873170319026442\n',
#    '36677512:automotive services,0.998545602756959\n',
#    '41809784:human care services,0.2470107632693205\n',
#    '43197012:technical services,0.33381665446187847\n',
#    '44299854:administrative services,0.19825111088377895\n',
#    '35678162:food and beverage,0.21062317915639442\n',
#    '44270153:food and beverage,0.19386538461435107\n',
#    '30387945:human care services,0.23179759803977776\n',
#    '44041134:human care services,0.950793578470015\n',
#    '29738561:human care services,0.2382649635063033\n',
#    '30507491:human care services,0.6768472766823982\n',
#    '29978334:human care services,0.7524981589428222\n',
#    '36776348:it or software services,0.2235047487612543\n',
#    '37953154:education,0.8169105056064995\n',
#    '40379385:human care services,0.43411724734531415\n',
#    '30337646:it or software services,0.17964570920873013\n',
#    '40805409:it or software services,0.2873669066427129\n',
#    '42759505:human care services,0.8225065119454903\n',
#    '28730071:it or software services,0.20395733290642884\n',
#    '39205267:technical services,0.34309370675798617\n',
#    '43518475:it or software services,0.2373286696991508\n',
#    '35718609:event services,0.9949392912213189\n',
#    '30337641:human care services,0.2193944576073478\n',
#    '42692710:human care services,0.5062923046701175\n',
#    '37091061:education,0.9754144095718583\n',
#    '42565823:human care services,0.496213687758906\n',
#    '43139177:human care services,0.201441142513113\n',
#    '38328236:it or software services,0.23866979358252943\n',
#    '40575407:it or software services,0.37000347594963073\n',
#    '33869959:human care services,0.6150757101482582\n',
#    '40818707:human care services,0.19422578565010912\n',
#    '43177415:human care services,0.7124283644328133\n',
#    '43326454:it or software services,0.37482549601013454\n',
#    '39760303:it or software services,0.35865440222264233\n',
#    '26704849:it or software services,0.2814529114281084\n',
#    '44510376:technical services,0.44166123375966887\n',
#    '38274821:technical services,0.5378726972693785\n',
#    '38605431:human care services,0.3202487088702509\n',
#    '35005359:technical services,0.6403583085628991\n',
#    '38317598:education,0.8392845010068464\n',
#    '44502753:food and beverage,0.18838036868665908\n',
#    '43108969:it or software services,0.2466405457550128\n',
#    '35382219:human care services,0.75027571957226\n',
#    '35854698:it or software services,0.38477105788865607\n',
#    '38606759:human care services,0.8010552415410455\n',
#    '39943530:human care services,0.2906934081190184\n',
#    '44037938:human care services,0.6621015467557563\n',
#    '44041199:human care services,0.8462217962202695\n',
#    '35714282:technical services,0.3097775355033434\n',
#    '42605575:administrative services,0.30995950844242215\n',
#    '37333089:human care services,0.6111657505017338\n',
#    '43975016:technical services,0.4513458209380977\n',
#    '40118796:it or software services,0.3102205251281741\n',
#    '43080063:human care services,0.19885948114547775\n',
#    '40780556:it or software services,0.3850669078907799\n',
#    '44408552:administrative services,0.20862554285712862\n',
#    '40758654:human care services,0.8107202608695615\n',
#    '43692528:technical services,0.40700076092293447\n',
#    '35714276:technical services,0.3187462302342862\n',
#    '35006680:it or software services,0.21767503886250386\n',
#    '43804570:it or software services,0.2770655993517638\n',
#    '35576079:administrative services,0.23300631842518063\n',
#    '34959021:it or software services,0.39713343695769177\n',
#    '35327443:human care services,0.789590565871881\n',
#    '38281100:event services,0.9929611387296851\n',
#    '33897188:human care services,0.5065848470371366\n',
#    '40321100:human care services,0.9419960875491702\n',
#    '29491842:human care services,0.6267261482983835\n',
#    '41417261:it or software services,0.5220626863688025\n',
#    '44057527:it or software services,0.2102158893070178\n',
#    '40078264:it or software services,0.4692550289624816\n',
#    '44057524:human care services,0.21814986231281364\n',
#    '44057521:it or software services,0.2184588311967318\n',
#    '42915531:administrative services,0.2283132905628534\n',
#    '44224264:human care services,0.510731283544806\n',
#    '43283658:it or software services,0.30081671601269233\n',
#    '36674444:it or software services,0.16973713657414333\n',
#    '33814839:technical services,0.3874579728490595\n',
#    '36000337:technical services,0.4939423089318247\n',
#    '43655588:it or software services,0.5022736734780258\n',
#    '43283654:it or software services,0.3191361524663191\n',
#    '35474135:technical services,0.5046242501851969\n',
#    '35474137:technical services,0.6688071286977837\n',
#    '39184521:it or software services,0.1724366382607526\n',
#    '35781068:technical services,0.41873441952431995\n',
#    '42941806:human care services,0.21451808294725005\n',
#    '42565871:human care services,0.6254656411170995\n',
#    '30149198:human care services,0.4036786557917945\n',
#    '44057510:it or software services,0.22644084524100935\n',
#    '43729628:human care services,0.7200873192805086\n',
#    '41304435:human care services,0.21010132279975155\n',
#    '36674430:automotive services,0.9960348108338981\n',
#    '35714298:technical services,0.33414935109526583\n',
#    '44297246:it or software services,0.28523982954336075\n',
#    '44230925:administrative services,0.1549981091325912\n',
#    '44427824:human care services,0.5614639725924876\n',
#    '43108934:human care services,0.6969681187341255\n',
#    '38196751:administrative services,0.21552679873491523\n',
#    '43349999:it or software services,0.18540671578826273\n',
#    '29946732:human care services,0.2162316116636025\n',
#    '39824011:it or software services,0.22516507769789051\n',
#    '40603196:it or software services,0.1871677072960147\n',
#    '39081288:human care services,0.1987114794839885\n',
#    '36391954:human care services,0.17243921818333238\n',
#    '42011580:human care services,0.2439048261610194\n',
#    '37418441:it or software services,0.22461499767852106\n',
#    '30149122:human care services,0.19083364446182077\n',
#    '34390073:human care services,0.3578277014109899\n',
#    '34709999:human care services,0.14615468792860548\n',
#    '44409859:administrative services,0.16332948690266544\n',
#    '44038391:human care services,0.8597720534480188\n',
#    '40825887:human care services,0.18413119510007006\n',
#    '32528196:human care services,0.1643791274934886\n',
#    '38404497:it or software services,0.2262945002280471\n',
#    '40079574:it or software services,0.25308615738188306\n',
#    '39344986:human care services,0.8153983038141381\n',
#    '39387234:human care services,0.9731767588340443\n',
#    '35716024:technical services,0.460060453175908\n',
#    '43982322:it or software services,0.411606383481116\n',
#    '35952250:it or software services,0.1664053999828097\n',
#    '35717358:technical services,0.4303716195919014\n',
#    '36274279:technical services,0.24647680137827307\n',
#    '43897091:technical services,0.4295020772189379\n',
#    '36274277:technical services,0.29574922253276015\n',
#    '26578779:it or software services,0.21027880404660682\n',
#    '41832157:human care services,0.4886312539324887\n',
#    '36277300:event services,0.9957058570716671\n',
#    '36519292:technical services,0.22290135461021254\n',
#    '38284261:event services,0.9981291084362198\n',
#    '36019785:human care services,0.6388506208604446\n',
#    '26578775:human care services,0.26697810974484415\n',
#    '43788894:technical services,0.3095224413305379\n',
#    '34653759:human care services,0.7752158604191816\n',
#    '41145489:technical services,0.44054318760252376\n',
#    '42462431:it or software services,0.3888593433500394\n',
#    '25756207:it or software services,0.2617052940388769\n',
#    '34107520:it or software services,0.17525833565509394\n',
#    '37909815:education,0.8847024249931849\n',
#    '36156213:food and beverage,0.20070482317576413\n',
#    '40116977:it or software services,0.2798107194672852\n',
#    '44448772:it or software services,0.22623261562442312\n',
#    '42192461:human care services,0.9624613953605635\n',
#    '38284255:event services,0.9980071514883446\n',
#    '39344995:human care services,0.6745874361327617\n',
#    '43256724:technical services,0.380682195788092\n',
#    '38284259:event services,0.9979637639319471\n',
#    '34674680:it or software services,0.2090729197220361\n',
#    '35716010:event services,0.9708200762259649\n',
#    '37952676:education,0.8409669684475686\n',
#    '42690117:human care services,0.6794562696383959\n',
#    '41428778:administrative services,0.19596552124690347\n',
#    '36274283:education,0.9593261574923999\n',
#    '35780603:technical services,0.4664827587603257\n',
#    '37091912:education,0.8519589847623379\n',
#    '43378478:human care services,0.2863706633155585\n',
#    '38681127:it or software services,0.23140438292661641\n',
#    '36588887:education,0.7869729148712561\n',
#    '33035643:administrative services,0.2605961331290424\n',
#    '43926078:transportation services,0.8647829887092456\n',
#    '36802497:human care services,0.2399300920716117\n',
#    '41756649:human care services,0.8787870869322547\n',
#    '37087890:education,0.6238469533630148\n',
#    '37091917:education,0.5924642773433022\n',
#    '29115238:human care services,0.6588616413738325\n',
#    '38298894:education,0.637801050548919\n',
#    '34259911:human care services,0.8333909707444953\n',
#    '43620900:human care services,0.357920423235855\n',
#    '43189483:human care services,0.7870285378364653\n',
#    '36892760:it or software services,0.3029924333091984\n',
#    '44427857:human care services,0.4611890296660091\n',
#    '33881674:food and beverage,0.1921692440339953\n',
#    '41617765:administrative services,0.2148177717719442\n',
#    '34234612:human care services,0.19569001783736592\n',
#    '35813148:technical services,0.44709555577267573\n',
#    '40149854:it or software services,0.2659392090473348\n',
#    '31078145:it or software services,0.19748454792972575\n',
#    '35577310:technical services,0.5416032191796765\n',
#    '39475629:it or software services,0.40384804103530164\n',
#    '39637847:it or software services,0.1682771192136179\n',
#    '39241722:human care services,0.26262402677523344\n',
#    '38387472:it or software services,0.23713313205013617\n',
#    '39207840:human care services,0.9362207378423925\n',
#    '40209325:human care services,0.209961060400294\n',
#    '41263410:human care services,0.33328293420761484\n',
#    '40950347:human care services,0.7443428227883387\n',
#    '43369546:it or software services,0.3600177284232697\n',
#    '42564577:human care services,0.39493238619500165\n',
#    '43369549:it or software services,0.3136379013614088\n',
#    '37097207:human care services,0.20752729508087125\n',
#    '40541265:it or software services,0.32732319660847503\n',
#    '43189475:human care services,0.7753222838235021\n',
#    '35717362:technical services,0.4470997182010301\n',
#    '39450340:technical services,0.48239501243710653\n',
#    '40678052:human care services,0.2124236823499918\n',
#    '35717360:technical services,0.48224690602102527\n',
#    '36275592:technical services,0.24987470186239838\n',
#    '40209317:human care services,0.19393012908562599\n',
#    '28996381:human care services,0.320473275997578\n',
#    '38011636:education,0.9661745721844658\n',
#    '33812240:it or software services,0.20482895906045653\n',
#    '44405456:transportation services,0.3373280200480729\n',
#    '33869132:human care services,0.32654642962293196\n',
#    '33812244:it or software services,0.22872917258049724\n',
#    '41847206:human care services,0.4808547841070224\n',
#    '40645160:it or software services,0.20707653699015083\n',
#    '44512949:transportation services,0.18970847258223825\n',
#    '40139641:human care services,0.1712580271809475\n',
#    '44473775:it or software services,0.25856915459618307\n',
#    '42838941:human care services,0.42843069004656886\n',
#    '44439876:human care services,0.22327704308207577\n',
#    '36168220:event services,0.9863270686356748\n',
#    '44473772:it or software services,0.24224434006156337\n',
#    '29032434:human care services,0.2769308924027759\n',
#    '43995681:it or software services,0.19609444794594827\n',
#    '35776534:food and beverage,0.21955223627178103\n',
#    '39263993:human care services,0.4183134199379825\n',
#    '42905338:human care services,0.6427403889856339\n',
#    '39260008:human care services,0.2618929190009445\n',
#    '42838938:human care services,0.22731681747408436\n',
#    '36005179:technical services,0.4190243740411887\n',
#    '40473591:human care services,0.49068403241394315\n',
#    '38303855:event services,0.9910480130723158\n',
#    '41335526:human care services,0.26669394262920665\n',
#    '28730008:human care services,0.18452252670142968\n',
#    '33383984:it or software services,0.9997276852925862\n',
#    '33908325:human care services,0.5768804573236205\n',
#    '38273590:education,0.8514519836623139\n',
#    '39260011:human care services,0.27708534884995234\n',
#    '43334898:human care services,0.29295596007018393\n',
#    '30487443:it or software services,0.17675113408183843\n',
#    '36156265:food and beverage,0.16193335566504105\n',
#    '30487444:it or software services,0.19064732769557605\n',
#    '37909821:education,0.8905942766462553\n',
#    '38272262:event services,0.9991796031873733\n',
#    '39260017:human care services,0.3144780195790136\n',
#    '33560956:human care services,0.4632262012737019\n',
#    '36624158:it or software services,0.2710049216587227\n',
#    '37052387:it or software services,0.452890565066127\n',
#    '44417622:human care services,0.4217667548247641\n',
#    '43517170:human care services,0.39880549882248095\n',
#    '40382974:human care services,0.47302534191050605\n',
#    '42272160:it or software services,0.2529392492698276\n',
#    '26180058:human care services,0.3206542936078045\n',
#    '36002914:technical services,0.32331253531303117\n',
#    '39387258:human care services,0.9822994526523281\n',
#    '33930222:human care services,0.7511454210360584\n',
#    '36168244:education,0.6798822189641432\n',
#    '42647351:technical services,0.4372938416413985\n',
#    '36995116:human care services,0.19267087390846221\n',
#    '25486212:it or software services,0.2152221478167712\n',
#    '36513958:technical services,0.2699612225828414\n',
#    '37908502:education,0.9215229864235184\n',
#    '43458161:it or software services,0.22719607403246006\n',
#    '43623152:human care services,0.28047024553753197\n',
#    '42062292:human care services,0.8105729836571377\n',
#    '44417630:human care services,0.4224471199564246\n',
#    '30647075:human care services,0.6468159757164433\n',
#    '40116989:it or software services,0.43557561013674334\n',
#    '35867155:technical services,0.47041874724598404\n',
#    '36624141:it or software services,0.33518428790529864\n',
#    '38284234:technical services,0.46339692591379394\n',
#    '39265716:human care services,0.7435460944369353\n',
#    '42812348:human care services,0.9238046773996436\n',
#    '34235917:human care services,0.34507127722254466\n',
#    '35380445:human care services,0.7159513438365279\n',
#    '36404002:pet services,0.9971883109851571\n',
#    '40942762:human care services,0.7831169979307241\n',
#    '38303831:event services,0.9978441224444483\n',
#    '43823696:human care services,0.19237104645383873\n',
#    '40473574:human care services,0.9075589036073778\n',
#    '40494498:human care services,0.2395433623834055\n',
#    '33699498:human care services,0.7971079821172602\n',
#    '33812161:it or software services,0.21712697436466574\n',
#    '40067624:human care services,0.5667381500820633\n',
#    '38012125:education,0.7943672672122649\n',
#    '34511660:it or software services,0.3061864142810435\n',
#    '40933039:hotel and hospitality,0.9985399399946646\n',
#    '44041839:it or software services,0.2691938424042233\n',
#    '26787306:human care services,0.47512333818163016\n',
#    '34326471:human care services,0.31996179789211765\n',
#    '44302301:it or software services,0.9996840281383147\n',
#    '26579226:it or software services,0.18609492271373987\n',
#    '38711496:human care services,0.5836500861919434\n',
#    '39079700:human care services,0.6584123794777114\n',
#    '33346894:it or software services,0.20763244262953415\n',
#    '37901251:education,0.7698749225841092\n',
#    '41417933:human care services,0.713347515272035\n',
#    '42593726:human care services,0.1958567844939728\n',
#    '39522325:it or software services,0.418396102294004\n',
#    '26787314:human care services,0.47250814490972726\n',
#    '26787312:human care services,0.496346809242885\n',
#    '40854345:human care services,0.4574523684864201\n',
#    '33584131:it or software services,0.15340791026159567\n',
#    '35780569:technical services,0.4748607104112577\n',
#    '43790105:technical services,0.24418210346652292\n',
#    '35780564:technical services,0.4217916744103818\n',
#    '44223889:human care services,0.767002142585714\n',
#    '35742254:technical services,0.6377561314692433\n',
#    '36198106:administrative services,0.1513268454118934\n',
#    '42016561:human care services,0.8010044419575361\n',
#    '37902549:technical services,0.3348532202312467\n',
#    '35608973:human care services,0.458292916352876\n',
#    '39122200:it or software services,0.9892626075318439\n',
#    '43936241:human care services,0.6623493362007736\n',
#    '36167879:event services,0.9964336796176836\n',
#    '30778236:human care services,0.5809331921988897\n',
#    '43792769:human care services,0.31134678319364056\n',
#    '30778239:human care services,0.6175239472607632\n',
#    '40167021:it or software services,0.22048132499892412\n',
#    '42844871:technical services,0.5020661409894106\n',
#    '40167024:human care services,0.2120951769142002\n',
#    '41870234:human care services,0.3446604264895743\n',
#    '33909604:food and beverage,0.19608423060970687\n',
#    '34031720:human care services,0.8053985442490329\n',
#    '37089428:education,0.8314682570459765\n',
#    '43533297:it or software services,0.33951784172346106\n',
#    '33850422:it or software services,0.2582603301827595\n',
#    '44426389:human care services,0.6934609480150369\n',
#    '33967755:it or software services,0.2549550028487173\n',
#    '41262294:human care services,0.37988965400000796\n',
#    '36589347:technical services,0.27921649429385265\n',
#    '37333948:it or software services,0.2981464217100045\n',
#    '35780572:technical services,0.4660112472388445\n',
#    '36002043:technical services,0.4399526961859583\n',
#    '40604644:it or software services,0.23423342505731679\n',
#    '39018789:human care services,0.529044048231246\n',
#    '37022300:technical services,0.3440061274719728\n',
#    '42705646:human care services,0.4102472107834605\n',
#    '44381120:hotel and hospitality,0.998757861105566\n',
#    '34232044:human care services,0.6818410557998086\n',
#    '36276169:event services,0.9892284630557372\n',
#    '42705642:human care services,0.4016481635395054\n',
#    '37043226:it or software services,0.2914239494072107\n',
#    '36276166:pet services,0.9954168929368923\n',
#    '40604642:it or software services,0.19703322778794496\n',
#    '42877764:administrative services,0.22749573436247908\n',
#    '44344137:human care services,0.1999502971529758\n',
#    '36277471:event services,0.9975191724403695\n',
#    '44371751:human care services,0.8533135955865783\n',
#    '43930914:human care services,0.4477966994160961\n',
#    '33836174:technical services,0.43913768224980926\n',
#    '40663663:it or software services,0.31770190067165577\n',
#    '44005305:human care services,0.9048385884455988\n',
#    '34669213:it or software services,0.3428340098258461\n',
#    '42517388:human care services,0.3072376590989258\n',
#    '33485837:human care services,0.16967338393844308\n',
#    '34889590:human care services,0.5595816886185607\n',
#    '40787884:human care services,0.24204844377944834\n',
#    '44316981:it or software services,0.9997533117529043\n',
#    '36153252:human care services,0.2622436134149585\n',
#    '36002054:technical services,0.5163066197084099\n',
#    '35896531:it or software services,0.2932209863370535\n',
#    '43364563:it or software services,0.35311423635152916\n',
#    '44340607:human care services,0.961614583363638\n',
#    '30778252:human care services,0.5785101271140194\n',
#    '30778253:human care services,0.617130246628196\n',
#    '33771968:technical services,0.6755199280574055\n',
#    '36167895:technical services,0.42131861416684335\n',
#    '34691130:human care services,0.32847542863426643\n',
#    '36277461:technical services,0.3806324370407043\n',
#    '37146523:it or software services,0.21764447611365542\n',
#    '39080730:human care services,0.21785727253506623\n',
#    '35022025:human care services,0.39437965317704804\n',
#    '35780511:technical services,0.41587600603303193\n',
#    '44052523:it or software services,0.22291701411286868\n',
#    '39891844:human care services,0.17447052495280002\n',
#    '40836503:human care services,0.2608556593575002\n',
#    '36438175:technical services,0.2692994497195773\n',
#    '37031266:food and beverage,0.21089013390867353\n',
#    '33850487:it or software services,0.36780710232585234\n',
#    '42693154:human care services,0.715222199529069\n',
#    '40590372:human care services,0.7635127910380498\n',
#    '40833471:human care services,0.7665521006104966\n',
#    '37779426:human care services,0.591085214309598\n',
#    '36589369:event services,0.9978238596324457\n',
#    '43533277:it or software services,0.3516637486487973\n',
#    '28463138:human care services,0.30224349421962743\n',
#    '43788681:technical services,0.2902607608492559\n',
#    '42533241:it or software services,0.329623596100842\n',
#    '36077604:it or software services,0.21129930224528137\n',
#    '43720270:administrative services,0.14672238238008642\n',
#    '29494760:human care services,0.5266954693168835\n',
#    '42728325:human care services,0.5075028414028797\n',
#    '43737939:human care services,0.8295688401637968\n',
#    '41163300:human care services,0.21846579122976154\n',
#    '43316083:it or software services,0.3404594580174742\n',
#    '43639662:human care services,0.9394070321968908\n',
#    '38281813:pet services,0.997768641433107\n',
#    '40686326:technical services,0.5296736581607795\n',
#    '44052511:it or software services,0.2628231623266739\n',
#    '37642505:technical services,0.41931903782260754\n',
#    '42593756:human care services,0.21703693649254435\n',
#    '34221344:it or software services,0.17434359250564865\n',
#    '37293112:administrative services,0.2798925576711004\n',
#    '43533263:it or software services,0.3975218358784527\n',
#    '36276118:event services,0.6297155048738964\n',
#    '36999452:transportation services,0.8554043283406223\n',
#    '43089349:it or software services,0.4685253329084279\n',
#    '36005105:technical services,0.40133073289476046\n',
#    '44504391:it or software services,0.3556315799141542\n',
#    '43170138:human care services,0.35582357311758733\n',
#    '41110805:it or software services,0.23193055595944537\n',
#    '29004286:human care services,0.30803922657893934\n',
#    '44429458:human care services,0.653639710276833\n',
#    '25783745:human care services,0.4659862586131733\n',
#    '33966461:administrative services,0.19512094163064148\n',
#    '38277789:technical services,0.21674794007564036\n',
#    '35225392:human care services,0.5199934090251963\n',
#    '43779768:human care services,0.8064796225472423\n',
#    '35343449:automotive services,0.997364263859283\n',
#    '25919877:it or software services,0.199829475345021\n',
#    '38275120:education,0.8152150399209908\n',
#    '40038274:technical services,0.3233843332858367\n',
#    '41002771:human care services,0.1630287338465595\n',
#    '36002087:event services,0.9851586735161957\n',
#    '39597094:administrative services,0.23774878993563964\n',
#    '39640655:it or software services,0.20638855608163634\n',
#    '36646431:pet services,0.9975552294118677\n',
#    '42641099:human care services,0.5638294317167748\n',
#    '35760941:it or software services,0.20467550821103225\n',
#    '44198128:human care services,0.7905741234020904\n',
#    '42729633:human care services,0.30244763348718406\n',
#    '37913248:education,0.6384766606548972\n',
#    '38602503:human care services,0.24179444290679467\n',
#    '36643327:pet services,0.9980910092406295\n',
#    '31005112:it or software services,0.49390869410840543\n',
#    '35352324:human care services,0.16436652095362747\n',
#    '44297260:it or software services,0.4740666929506316\n',
#    '38539521:it or software services,0.3860646063144294\n',
#    '28831497:it or software services,0.2674722504032223\n',
#    '44385556:human care services,0.2666552811593256\n',
#    '34471954:human care services,0.21079576874610317\n',
#    '41455366:human care services,0.4067065786882826\n',
#    '42339123:human care services,0.5805788652881432\n',
#    '44504336:it or software services,0.33575380854828885\n',
#    '41455364:human care services,0.3471079221607606\n',
#    '29387515:it or software services,0.1984169411740559\n',
#    '43691401:human care services,0.23813815515261338\n',
#    '40471881:human care services,0.9218097708348095\n',
#    '43040930:human care services,0.28213645834130435\n',
#    '44302385:it or software services,0.9994720153320541\n',
#    '41333950:human care services,0.8103947060118329\n',
#    '40852574:it or software services,0.28803120235423696\n',
#    '36642003:education,0.6658145388981556\n',
#    '30021510:human care services,0.22319174160450475\n',
#    '34028978:human care services,0.584245581678423\n',
#    '35781009:event services,0.9938924072224865\n',
#    '33609148:human care services,0.22030013257820968\n',
#    '35352331:human care services,0.16495888221246366\n',
#    '39398924:human care services,0.280063912913404\n',
#    '40166550:it or software services,0.24432867578905393\n',
#    '41548422:human care services,0.43630804564091896\n',
#    '39747477:it or software services,0.22328420894817141\n',
#    '41179720:it or software services,0.2468575002908908\n',
#    '43892191:it or software services,0.35885864665550365\n',
#    '25717404:human care services,0.24258763965465138\n',
#    '44297269:it or software services,0.3682574708079019\n',
#    '40818688:human care services,0.21892754168311643\n',
#    '41455372:human care services,0.3652257330712564\n',
#    '43971406:human care services,0.40039978185519853\n',
#    '35290446:human care services,0.4869091142988768\n',
#    '35854703:it or software services,0.2877470864980668\n',
#    '43892192:it or software services,0.43559670657062477\n',
#    '43971400:human care services,0.3561981968303956\n',
#    '37912775:event services,0.9954949214472559\n',
#    '39259943:human care services,0.2570758339949244\n',
#    '41901020:human care services,0.23495494194009903\n',
#    '43971402:human care services,0.3294769156876142\n',
#    '44430474:human care services,0.7637087905493903\n',
#    '37101607:education,0.9014941920242187\n',
#    '33048168:human care services,0.1974730919339112\n',
#    '42287176:it or software services,0.21628026169670297\n',
#    '42366716:it or software services,0.37338389043171216\n',
#    '39078482:human care services,0.6898734959933237\n',
#    '33609158:it or software services,0.18867846424503476\n',
#    '43620230:human care services,0.45401902175126496\n',
#    '35716843:event services,0.9949553128050217\n',
#    '36466207:technical services,0.277871316765986\n',
#    '43790193:technical services,0.3371309210080649\n',
#    '38283631:event services,0.9991211720031424\n',
#    '44422840:human care services,0.7011808043222172\n',
#    '43720282:technical services,0.8433753634090525\n',
#    '30030439:human care services,0.1827944955793904\n',
#    '44046662:administrative services,0.26669597045430377\n',
#    '39080797:human care services,0.18184459921790525\n',
#    '44372257:human care services,0.8844519938095546\n',
#    '43498180:human care services,0.23301708015810765\n',
#    '43572859:hotel and hospitality,0.9978449883937219\n',
#    '39597969:it or software services,0.24406872637575652\n',
#    '40935644:it or software services,0.2061844216429648\n',
#    '35071011:it or software services,0.226577222491091\n',
#    '36677591:automotive services,0.9935094322050458\n',
#    '35226681:human care services,0.6843619786046146\n',
#    '39522385:it or software services,0.3491778128698961\n',
#    '33609168:human care services,0.1804500775772634\n',
#    '40073432:it or software services,0.3038722510145962\n',
#    '42014768:human care services,0.6938313496115918\n',
#    '44409140:technical services,0.4083113271971959\n',
#    '33609165:human care services,0.17612990909933876\n',
#    '40761201:technical services,0.38531441941661376\n',
#    '42287162:transportation services,0.5468145388868816\n',
#    '41125086:it or software services,0.18883203057013345\n',
#    '40818664:human care services,0.20000349877353302\n',
#    '39640691:it or software services,0.22085659227576246\n',
#    '34048556:it or software services,0.18716047228880597\n',
#    '29620320:human care services,0.19096133682730315\n',
# ...
#    'topic 0\n',
#    '35864342:veterinary,USER\n',
#    '37910133:animal care,0.04093174086617628,CLASSIFIER,0.8990845258763976\n',
#    '36001928:animal care,0.039071861755148464,CLASSIFIER,0.8715330122187578\n',
#    '36274463:animal care,0.03713165002763445,CLASSIFIER,0.8877407227010947\n',
#    '37952460:animal care,0.034780742421218466,CLASSIFIER,0.949532053581852\n',
#    '38299773:animal care,0.0315956057897105,CLASSIFIER,0.849754094271073\n',
#    '36438848:animal care,0.02968570968290692,CLASSIFIER,0.9057928607694047\n',
#    '36517336:animal care,0.028440495854835192,CLASSIFIER,0.8164989749898918\n',
#    '36437637:animal care,0.0283979425296025,CLASSIFIER,0.8210311495658956\n',
#    '35904734:animal care,0.027746509635737576,CLASSIFIER,0.811325439675941\n',
#    '38281795:animal care,0.026834699200544456,CLASSIFIER,0.9394582296280604\n',
#    '38283931:animal care,0.02390397256715473,CLASSIFIER,0.801497989339824\n',
#    '36001932:animal care,0.023878153846543945,CLASSIFIER,0.8206275530725905\n',
#    '36467441:animal care,0.023759480685529532,CLASSIFIER,0.8772314804726694\n',
#    '36276166:animal care,0.021890592839312238,CLASSIFIER,0.8894393705572199\n',
#    '36169471:animal care,0.02163466056803763,CLASSIFIER,0.9465501112514801\n',
#    '36404002:animal care,0.019670356268173893,CLASSIFIER,0.8746734884780729\n',
#    '36589078:animal care,0.019313042282868013,CLASSIFIER,0.9596857987454114\n',
#    '36352644:NONE,0.018532355456396796\n',
#    '36276499:animal care,0.017973757898143965,CLASSIFIER,0.8538124354451373\n',
#    'topic 1\n',
#    '29491337:heathcare,USER\n',
#    '35136518:heathcare,USER\n',
#    '35022025:heathcare,USER\n',
#    '26112684:NONE,0.1964055929192188\n',
#    '41358027:NONE,0.18856469074809512\n',
#    '41465581:NONE,0.16034447668263216\n',
#    '34889590:NONE,0.15932292908223367\n',
#    '41059024:NONE,0.1577429943118605\n',
#    '39387234:NONE,0.1575242949592883\n',
#    '41465678:NONE,0.15584673497427282\n',
#    '37223507:NONE,0.15547712388710888\n',
#    '37160092:NONE,0.1544576932594326\n',
#    '36674018:NONE,0.15265210041880467\n',
#    '35228367:NONE,0.15208677858629446\n',
#    '28926392:NONE,0.1499300480035651\n',
#    '38254607:NONE,0.1484891423700275\n',
#    '37333089:NONE,0.146836548919218\n',
#    '37588247:NONE,0.14661730178453272\n',
#    '34720561:NONE,0.14179797519160273\n',
#    '37308855:NONE,0.1395757206698085\n',
#    'topic 2\n',
#    '44512949:commercial driver,USER\n',
#    '36674514:automotive,USER\n',
#    '42287162:commercial driver,USER\n',
#    '26591595:NONE,0.20076534191710207\n',
#    '35343154:NONE,0.20064795237039565\n',
#    '39883624:auto maintenance,0.20028920879015208,CLASSIFIER,0.9925284727342031\n',
#    '40604852:auto maintenance,0.2002159629674115,CLASSIFIER,0.9955662455258484\n',
#    '36671787:NONE,0.1999568957427775\n',
#    '36674918:NONE,0.199713181903025\n',
#    '36677659:NONE,0.19921571227631618\n',
#    '36672923:NONE,0.1991724280812573\n',
#    '36677278:NONE,0.1990824686187203\n',
#    '30030439:auto maintenance,0.19898252532819077,CLASSIFIER,0.9978084675683077\n',
#    '35352629:NONE,0.1989758792876188\n',
#    '35341217:NONE,0.19860591901704852\n',
#    '36674444:NONE,0.19852003645444333\n',
#    '36677446:NONE,0.198313687550806\n',
#    '42592923:auto maintenance,0.1983107882137998,CLASSIFIER,0.9902648728381596\n',
#    '40818868:auto maintenance,0.19806044618588367,CLASSIFIER,0.9971861926582386\n',
#    '42593870:auto maintenance,0.19804112035379068,CLASSIFIER,0.9975999012145901\n',
#    'topic 3\n',
#    '37843364:housekeeping,USER\n',
#    '44195724:hospitality,USER\n',
#    '35828647:housekeeping,USER\n',
#    '42293122:hospitality,USER\n',
#    '43498395:NONE,0.19269593449877287\n',
#    '41091081:NONE,0.1920878655806285\n',
#    '44473102:NONE,0.16664100028778586\n',
#    '43904909:NONE,0.1639078524660597\n',
#    '44195807:NONE,0.16202128410793665\n',
#    '28853978:NONE,0.1541858130436381\n',
#    '39388097:it,0.13481348418876227,CLASSIFIER,0.07364673642864387\n',
#    '41116223:NONE,0.13259240277042023\n',
#    '40933844:NONE,0.12712068492316014\n',
#    '42999251:NONE,0.11700835998831272\n',
#    '44444033:NONE,0.10113780505945513\n',
#    '44195485:NONE,0.09904985820267521\n',
#    '41116222:NONE,0.09883491369181037\n',
#    '44439768:NONE,0.09413561912903705\n',
#    '38731748:NONE,0.08441059274754836\n',
#    '44381379:NONE,0.08416067458693237\n',
#    'topic 4\n',
#    '38636613:finance,USER\n',
#    '34511407:finance,USER\n',
#    '34709999:finance,USER\n',
#    '40805409:NONE,0.19753634779040385\n',
#    '38684983:NONE,0.1969176924100575\n',
#    '43121953:NONE,0.19579238485420208\n',
#    '44369582:NONE,0.19527171121663545\n',
#    '39826955:NONE,0.19498563163636876\n',
#    '39599357:NONE,0.19494628081873477\n',
#    '34637999:customer service,0.19453709413370485,CLASSIFIER,0.23266345721807805\n',
#    '37293305:NONE,0.19396036924615614\n',
#    '36000854:customer service,0.19353086910420578,CLASSIFIER,0.24049447224804044\n',
#    '41432964:NONE,0.19348941424279917\n',
#    '44400016:NONE,0.19346140167324266\n',
#    '41769790:NONE,0.1932224807989137\n',
#    '35008146:NONE,0.1931061202367682\n',
#    '38424638:customer service,0.19310068351270818,CLASSIFIER,0.24789356426388187\n',
#    '41146257:customer service,0.1924386327133016,CLASSIFIER,0.338902652806042\n',
#    '36787184:NONE,0.19210493259873948\n',
#    '39027637:NONE,0.19197978349690606\n',
#    'topic 5\n',
#    '40266373:heathcare,USER\n',
#    '27133798:heathcare,USER\n',
#    '40266623:NONE,0.17281194951773132\n',
#    '40266428:NONE,0.163447573302576\n',
#    '40742844:NONE,0.15802140542103094\n',
#    '40265545:NONE,0.15659836777117253\n',
#    '40321240:health and wellness,0.15486174404197434,CLASSIFIER,0.9103437185844075\n',
#    '39078482:NONE,0.15144976518117487\n',
#    '40321100:health and wellness,0.14981535652914518,CLASSIFIER,0.8037500642709199\n',
#    '42938708:NONE,0.14901787973865552\n',
#    '40321066:health and wellness,0.14885891101766585,CLASSIFIER,0.8566021415125573\n',
#    '43904314:NONE,0.1482050268972658\n',
#    '40321198:health and wellness,0.1481835890267157,CLASSIFIER,0.9600789958637256\n',
#    '41232084:health and wellness,0.1479788757925479,CLASSIFIER,0.9730627387103531\n',
#    '40321581:NONE,0.14792117817953043\n',
#    '40321210:health and wellness,0.14676975225256947,CLASSIFIER,0.9815938827050475\n',
#    '40320957:health and wellness,0.14520346939569181,CLASSIFIER,0.9754959495607781\n',
#    '43572127:NONE,0.14311975698771817\n',
#    '43496922:NONE,0.14281864002084094\n',
#    '39079700:NONE,0.14202884262327117\n',
#    'topic 6\n',
#    '44223551:child care,USER\n',
#    '41759271:child care,USER\n',
#    '38600271:NONE,0.20645812971975536\n',
#    '34794246:NONE,0.20627044859719537\n',
#    '34001173:NONE,0.20594287983609394\n',
#    '42856704:NONE,0.20573985802054406\n',
#    '34033102:NONE,0.20560028479021475\n',
#    '41036704:NONE,0.20559045277396715\n',
#    '34084762:NONE,0.20524078188184633\n',
#    '40193608:NONE,0.20518718804780797\n',
#    '34929441:NONE,0.20508271307383544\n',
#    '44224843:NONE,0.20502707160518835\n',
#    '41863135:NONE,0.20502580438576565\n',
#    '34234612:NONE,0.2050058592633627\n',
#    '34326471:NONE,0.2050034842212761\n',
#    '36097460:NONE,0.20486731073577183\n',
#    '42686535:NONE,0.2048447709767561\n',
#    '43857678:NONE,0.2048420462056414\n',
#    '39624417:NONE,0.20483125521379733\n',
#    '33780652:NONE,0.20473773325716332\n',
#    'topic 7\n',
#    '40195595:food service,USER\n',
#    '35678162:housekeeping,USER\n',
#    '41368423:retail,USER\n',
#    '26579100:food service,USER\n',
#    '43945270:NONE,0.2018901279378459\n',
#    '35246921:NONE,0.20023912048605158\n',
#    '35859339:NONE,0.19994024502168115\n',
#    '15248653:NONE,0.19949200194034208\n',
#    '42766723:NONE,0.19925789302780594\n',
#    '42766719:NONE,0.19908435809416988\n',
#    '38841685:NONE,0.19905155999348143\n',
#    '40686285:NONE,0.1987290648348456\n',
#    '8924818:NONE,0.1986265174066653\n',
#    '31373600:NONE,0.19844254245469078\n',
#    '34220487:NONE,0.197553241160302\n',
#    '41532549:NONE,0.1973088306574629\n',
#    '33215766:NONE,0.19719962885131828\n',
#    '9972101:NONE,0.19718077988722296\n',
#    '40961229:NONE,0.1971320207427538\n',
#    '31170817:NONE,0.19621253729471427\n',
#    'topic 8\n',
#    '30656839:NONE,0.19831194399649718\n',
#    '43691707:health and wellness,0.1954552726076991,CLASSIFIER,0.9575497938210246\n',
#    '43368537:health and wellness,0.1952382161359994,CLASSIFIER,0.8747410465096377\n',
#    '43499047:NONE,0.19485175793050888\n',
#    '40435773:health and wellness,0.19437327114136946,CLASSIFIER,0.975492321441783\n',
#    '43627123:NONE,0.19287505535020658\n',
#    '43627094:NONE,0.1928452055967769\n',
#    '38659358:NONE,0.19245082422626364\n',
#    '43691688:health and wellness,0.1923403378937188,CLASSIFIER,0.9420224067186133\n',
#    '43691692:health and wellness,0.19204634129931777,CLASSIFIER,0.8979794608191809\n',
#    '43084047:health and wellness,0.19191880467233763,CLASSIFIER,0.9699234203994097\n',
#    '43498180:NONE,0.19190762751209217\n',
#    '38754426:health and wellness,0.1913727315210083,CLASSIFIER,0.9792217018692668\n',
#    '41286374:health and wellness,0.19093877907477724,CLASSIFIER,0.9045102332330589\n',
#    '39398862:NONE,0.18968845045642752\n',
#    '33762769:NONE,0.18951029320333607\n',
#    '43004499:NONE,0.18941222369802066\n',
#    '43292171:NONE,0.18940123906103154\n',
#    '40709573:NONE,0.18853521766599105\n',
#    '39399190:NONE,0.1881752833702369\n',
#    'topic 9\n',
#    '43565410:construction,USER\n',
#    '33969591:mechanical engineer,USER\n',
#    '34337043:construction,USER\n',
#    '37524325:mechanical engineer,USER\n',
#    '33620358:manufacturing,USER\n',
#    '34119949:manufacturing,USER\n',
#    '35901818:mechanical engineer,USER\n',
#    '41545303:NONE,0.19928799103354983\n',
#    '41719804:auto maintenance,0.1979997162223269,CLASSIFIER,0.9199597348262151\n',
#    '43720043:NONE,0.19503213533724845\n',
#    '40562922:NONE,0.1950121747055894\n',
#    '36318662:NONE,0.19406235035698596\n',
#    '39638023:NONE,0.1923653021536054\n',
#    '34713979:NONE,0.19202421798217478\n',
#    '42967058:NONE,0.19180099654498117\n',
#    '35813878:trade vocation,0.19133754211695536,CLASSIFIER,0.48585726790126355\n',
#    '40036923:trade vocation,0.19098020617948247,CLASSIFIER,0.4218906865686303\n',
#    '24877410:trade vocation,0.19086949147681048,CLASSIFIER,0.48129664113891923\n',
#    '35577310:NONE,0.1904479468462008\n',
#    '44300494:NONE,0.19022145813813768\n',
#    'topic 10\n',
#    '43873331:heathcare,USER\n',
#    '26791551:heathcare,USER\n',
#    '39836807:NONE,0.18675847409074575\n',
#    '39255022:technician,0.18592237405901726,CLASSIFIER,0.9973442673279643\n',
#    '39241849:NONE,0.18514978395612505\n',
#    '39256217:technician,0.18506736532691745,CLASSIFIER,0.9924737613527779\n',
#    '30520837:technician,0.18494592383761407,CLASSIFIER,0.9941727111771105\n',
#    '30647579:technician,0.18399540323502214,CLASSIFIER,0.9964586900590315\n',
#    '43408575:NONE,0.1839104466826757\n',
#    '39256477:technician,0.18385041046656575,CLASSIFIER,0.9978797573254967\n',
#    '39401619:NONE,0.17868600513159924\n',
#    '35709821:NONE,0.17674770540272333\n',
#    '44448602:technician,0.17582333547221796,CLASSIFIER,0.6259928446427078\n',
#    '39401541:NONE,0.17536661915697963\n',
#    '29867830:NONE,0.1753550795386409\n',
#    '39401705:NONE,0.1747023067573998\n',
#    '39401646:NONE,0.17458088091991436\n',
#    '30776885:NONE,0.1742873580742699\n',
#    '29174048:technician,0.17375328143237206,CLASSIFIER,0.9991014587490301\n',
#    '42941770:NONE,0.17345842196443903\n'],
#   'User labels:': [{'label': 'security', 'posting_id': '24967424'},
#    {'label': 'food service', 'posting_id': '26579100'},
#    {'label': 'heathcare', 'posting_id': '26791551'},
#    {'label': 'heathcare', 'posting_id': '27133798'},
#    {'label': 'mechanical engineer', 'posting_id': '28949040'},
#    {'label': 'banking', 'posting_id': '29000356'},
#    {'label': 'heathcare', 'posting_id': '29491337'},
#    {'label': 'software engineer', 'posting_id': '33384297'},
#    {'label': 'manufacturing', 'posting_id': '33620358'},
#    {'label': 'software engineer', 'posting_id': '33808073'},
#    {'label': 'mechanical engineer', 'posting_id': '33969591'},
#    {'label': 'beauty and spa', 'posting_id': '34081002'},
#    {'label': 'manufacturing', 'posting_id': '34119949'},
#    {'label': 'construction', 'posting_id': '34337043'},
#    {'label': 'finance', 'posting_id': '34511407'},
#    {'label': 'finance', 'posting_id': '34709999'},
#    {'label': 'human resources', 'posting_id': '34960213'},
#    {'label': 'software engineer', 'posting_id': '34964671'},
#    {'label': 'heathcare', 'posting_id': '35022025'},
#    {'label': 'heathcare', 'posting_id': '35136518'},
#    {'label': 'software engineer', 'posting_id': '35152574'},
#    {'label': 'warehouse worker', 'posting_id': '35597134'},
#    {'label': 'housekeeping', 'posting_id': '35678162'},
#    {'label': 'marketing', 'posting_id': '35721623'},
#    {'label': 'housekeeping', 'posting_id': '35828647'},
#    {'label': 'veterinary', 'posting_id': '35864342'},
#    {'label': 'mechanical engineer', 'posting_id': '35901818'},
#    {'label': 'construction', 'posting_id': '36167330'},
#    {'label': 'construction', 'posting_id': '36168740'},
#    {'label': 'automotive', 'posting_id': '36674514'},
#    {'label': 'heathcare', 'posting_id': '36876792'},
#    {'label': 'security', 'posting_id': '36995116'},
#    {'label': 'teaching', 'posting_id': '37091061'},
#    {'label': 'retail', 'posting_id': '37099325'},
#    {'label': 'heathcare', 'posting_id': '37450291'},
#    {'label': 'mechanical engineer', 'posting_id': '37524325'},
#    {'label': 'housekeeping', 'posting_id': '37843364'},
#    {'label': 'retail', 'posting_id': '37864323'},
#    {'label': 'food service', 'posting_id': '38192417'},
#    {'label': 'warehouse worker', 'posting_id': '38299916'},
#    {'label': 'construction', 'posting_id': '38300365'},
#    {'label': 'finance', 'posting_id': '38636613'},
#    {'label': 'security', 'posting_id': '39719111'},
#    {'label': 'retail', 'posting_id': '40081298'},
#    {'label': 'manufacturing', 'posting_id': '40139596'},
#    {'label': 'food service', 'posting_id': '40195595'},
#    {'label': 'security', 'posting_id': '40206964'},
#    {'label': 'heathcare', 'posting_id': '40266373'},
#    {'label': 'software engineer', 'posting_id': '40562389'},
#    {'label': 'retail', 'posting_id': '41368423'},
#    {'label': 'software engineer', 'posting_id': '41624326'},
#    {'label': 'retail', 'posting_id': '41657916'},
#    {'label': 'child care', 'posting_id': '41759271'},
#    {'label': 'software engineer', 'posting_id': '41904583'},
#    {'label': 'software engineer', 'posting_id': '41904621'},
#    {'label': 'commercial driver', 'posting_id': '42287162'},
#    {'label': 'hospitality', 'posting_id': '42293122'},
#    {'label': 'software engineer', 'posting_id': '42668523'},
#    {'label': 'software engineer', 'posting_id': '43036494'},
#    {'label': 'hospitality', 'posting_id': '43068092'},
#    {'label': 'software engineer', 'posting_id': '43313055'},
#    {'label': 'software engineer', 'posting_id': '43370306'},
#    {'label': 'construction', 'posting_id': '43565410'},
#    {'label': 'construction', 'posting_id': '43593282'},
#    {'label': 'software engineer', 'posting_id': '43646919'},
#    {'label': 'heathcare', 'posting_id': '43873331'},
#    {'label': 'hospitality', 'posting_id': '44195724'},
#    {'label': 'child care', 'posting_id': '44223551'},
#    {'label': 'software engineer', 'posting_id': '44302301'},
#    {'label': 'software engineer', 'posting_id': '44307064'},
#    {'label': 'software engineer', 'posting_id': '44391712'},
#    {'label': 'software engineer', 'posting_id': '44502194'},
#    {'label': 'commercial driver', 'posting_id': '44512949'}],
#   'header': ['johnmoon\n',
#    '-----------------------------------------------\n',
#    'time= 1507309613635_89:46\n',
#    'isFinal= false\n',
#    'purity = -1.0\n',
#    'size of label set = 21\n',
#    'final event = SAVELABEL:Labelview=False,savetime=1507309613.151,id=28949040,currlabel=NONE,def=NONE,confidence=NONE,newlabel=mechanical engineer,topicIndex=15,pos=13,positionUnlabeled=10,optTopic=15,waitTime=4.58299994468689,button=,min=89,sec=46\n',
#    '-----------------------------------------------\n']}}
