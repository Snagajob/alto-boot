# %%
import os
logs_dirs = [
    "data/large_sample_20/log/", 
    "data/large_v2_sample_20/log/", 
    "data/large_sample_40/log/",
    "data/large_sample_80/log/"
]
users = {logs_dir:list({x.split("_")[0] for x in os.listdir(logs_dir)}) for logs_dir in logs_dirs}
users
# Out:
# {'data/large_sample_20/log/': ['rmealey2',
#   'Jonathan Daberkow',
#   'Xun',
#   'Aash',
#   'jason.kowalewski@snagajob.com',
#   'johnmoon'],
#  'data/large_sample_40/log/': ['rmealey',
#   'ghost-rider',
#   'Xun',
#   'jason.kowalewski@snagajob.com',
#   'johnmoon'],
#  'data/large_sample_80/log/': ['jmexp1'],
#  'data/large_v2_sample_20/log/': ['rmealey',
#   'chrislin',
#   'ghost-rider',
#   'Aash',
#   'johnmoon']}

# %%
def parse_logfile_name(logfile_name, logs_dir):
    out = dict()
    out["filename"] = logfile_name
    out["dir"] = logs_dir + "/"
    d = logfile_name[0:-4].split("_")
    out["user"] = d[0]
    if d[1] == "log":
        out["date"] = d[3]
        out["time"] = d[4]
        out["n"] = d[2]
        out["label_file"] = False
    else:
        out["date"] = d[1]
        out["time"] = d[2]
        out["label_file"] = True
        out["update"] = "update" in d
    return out


    
def get_last_update(logs_dir, user):
    user_files = [parse_logfile_name(x, logs_dir)
                  for x in os.listdir(logs_dir)
                  if x.find(user) >= 0]
    label_files = [f for f in user_files if f["label_file"]]
    label_files = sorted(label_files, key=lambda x: (x["date"], x["time"]))
    last_file = label_files[-1]
    return last_file
    
    
user_files = {logs_dir:{user:get_last_update(logs_dir, user) for user in users} for logs_dir, users in users.items()}
    
user_files.keys()
# Out:
# dict_keys(['data/large_sample_20/log/', 'data/large_v2_sample_20/log/', 'data/large_sample_40/log/', 'data/large_sample_80/log/'])

# %%
from collections import defaultdict

def parse_label_file(label_file):
    if label_file["update"]:
        header_n = -1
    else:
        header_n = 0 
    headers = ["TOP IDS:", "User labels:", "Classification results:", "All classification results:", ""]
    out = defaultdict(lambda: [])
    with open(label_file["dir"] + label_file["filename"]) as f:
        for i in range(8):
            out["header"].append(f.readline())
        for l in f:
            if l.strip() == headers[header_n+1]:
                header_n = header_n + 1
            if l.strip() not in headers:
                out[headers[header_n]].append(l)
    out["Classification results:"] = [parse_label(r) for r in out["Classification results:"]]
    out["User labels:"] = [parse_label(r) for r in out["User labels:"]]
    out["All classification results:"] = [parse_label(r) for r in out["All classification results:"]]
    out["IsFinal"] = label_file["update"] is False
    out = {k:v for k,v in out.items()}
    return out
                

def parse_label(r):
    out = dict()
    d = r.strip().split(",")
    out["posting_id"], out["label"] = d[0].split(":")
    if len(d) == 2:
        out["score"] = float(d[1])
    return out

    
user_labels = {l:{user:parse_label_file(user_files[l][user]) for user in user_files[l].keys()} for l in user_files.keys()}
user_labels.keys()
# Out:
# dict_keys(['data/large_sample_20/log/', 'data/large_v2_sample_20/log/', 'data/large_sample_40/log/', 'data/large_sample_80/log/'])

# %%
label_sets = {l:{user:sorted({r["label"] for r in user_labels[l][user]["User labels:"]})
                 for user in user_labels[l]} for l in user_labels.keys()}
label_sets
# Out:
# {'data/large_sample_20/log/': {'Aash': ['animal care',
#    'business or financial services',
#    'catering',
#    'customer support',
#    'emergency services',
#    'engineering',
#    'food services',
#    'home services',
#    'hospitality',
#    'human care services',
#    'it',
#    'machine operator',
#    'medical services',
#    'music instruction',
#    'sales',
#    'transportation services'],
#   'Jonathan Daberkow': ['accounting',
#    'automotive',
#    'business administration',
#    'childcare',
#    'construction',
#    'customer service',
#    'education',
#    'engineering',
#    'facility maintenance',
#    'food and restaurant',
#    'general contracting',
#    'healthcare',
#    'hospitality',
#    'petcare',
#    'police fire ems',
#    'real estate',
#    'retail',
#    'software engineering',
#    'truck driving',
#    'tutoring',
#    'warehouse and production'],
#   'Xun': ['administratives',
#    'business and management',
#    'childcare',
#    'customer service',
#    'education and teaching',
#    'finance and accounting',
#    'foodservice and restaurant',
#    'healthcare and phrama',
#    'home and building improvements and services',
#    'hospitality',
#    'information technology',
#    'petcare',
#    'public service',
#    'retail',
#    'sales and marketing',
#    'skilled trade technician',
#    'supply chain and logistics',
#    'trucking and transportation',
#    'warehousing'],
#   'jason.kowalewski@snagajob.com': ['accounting and finance',
#    'administrative',
#    'automotive',
#    'business administration',
#    'childcare',
#    'computers and software',
#    'construction',
#    'contracting and renovation',
#    'customer service',
#    'education',
#    'food service',
#    'healthcare',
#    'janitorial',
#    'manufacturing',
#    'marketing',
#    'paralegal',
#    'pet care',
#    'restaurant',
#    'retail',
#    'safety and security',
#    'sales',
#    'service technician',
#    'skilled manufacturing',
#    'skilled service technician',
#    'transportation',
#    'warehouse jobs'],
#   'johnmoon': ['animal services',
#    'call center',
#    'child care',
#    'clerical',
#    'construction',
#    'education',
#    'finance',
#    'food service',
#    'healthcare',
#    'hospitality',
#    'manufacturing',
#    'public services',
#    'retail',
#    'sales and support',
#    'security',
#    'software engineering',
#    'trucking and transportation',
#    'warehouse personnel'],
#   'rmealey2': ['admin and paraprofessional',
#    'childcare and early education',
#    'direct sales and marketing',
#    'event services',
#    'food and beverage',
#    'health and wellness direct care',
#    'health and wellness professional',
#    'health and wellness technician',
#    'home contracting renovation repair',
#    'hospitality',
#    'personal services and instruction',
#    'pet services',
#    'professional',
#    'retail',
#    'security services',
#    'trucking and transportation',
#    'warehouse industrial manufacturing professional',
#    'warehouse industrial manufacturing trades']},
#  'data/large_sample_40/log/': {'Xun': ['administrative',
#    'customer service',
#    'finance',
#    'healthcare and wellness',
#    'home improvement home services',
#    'hotel and hospitality',
#    'human resource',
#    'pet care',
#    'real estate',
#    'restaurant food service',
#    'retail',
#    'security',
#    'technician skilled trade'],
#   'ghost-rider': ['food and beverage',
#    'health and wellness',
#    'healthcare',
#    'security'],
#   'jason.kowalewski@snagajob.com': ['aviation technicians',
#    'biotechnology',
#    'catering',
#    'childcare',
#    'computers and software',
#    'construction',
#    'customer support',
#    'education',
#    'engineering',
#    'finance',
#    'food and restaurant',
#    'healthcare',
#    'hospitality',
#    'legal',
#    'manufacturing',
#    'marketing',
#    'movers',
#    'photography',
#    'real estate',
#    'retail',
#    'security',
#    'skilled manufacturing',
#    'tutoring',
#    'warehouse'],
#   'johnmoon': ['food and beverage',
#    'heathcare',
#    'pharmacy',
#    'security',
#    'software engineer'],
#   'rmealey': ['food and beverage',
#    'health and wellness',
#    'pharmacy',
#    'security services']},
#  'data/large_sample_80/log/': {'jmexp1': ['admin and clerical',
#    'animal service',
#    'automotive maintenance',
#    'automotive services',
#    'business professional',
#    'business services',
#    'child care',
#    'customer support',
#    'education professional',
#    'education teacher',
#    'engineering building and civil',
#    'engineering software',
#    'engineering systems',
#    'facility construction',
#    'facility maintenance',
#    'finance business',
#    'finance personal',
#    'food service management',
#    'food service serving',
#    'food services preparation',
#    'food services serving',
#    'food services worker',
#    'healthcare administration',
#    'healthcare nursing',
#    'healthcare personal',
#    'healthcare services',
#    'hospitality housekeeping',
#    'hospitality services',
#    'human resources administration',
#    'manufactoring maintenance',
#    'manufactoring operator',
#    'manufactoring services',
#    'manufactoring trades',
#    'pharmacy services',
#    'public services corrections',
#    'real estate',
#    'recreation services',
#    'retail',
#    'retail grocery',
#    'retail specialty',
#    'sales',
#    'security',
#    'transportation cdl',
#    'warehouse administration',
#    'warehouse labor',
#    'warehouse services']},
#  'data/large_v2_sample_20/log/': {'Aash': ['administrative services',
#    'automotive services',
#    'education',
#    'event services',
#    'food and beverage',
#    'hotel and hospitality',
#    'human care services',
#    'it or software services',
#    'pet services',
#    'technical services',
#    'transportation services'],
#   'chrislin': ['accounting finance',
#    'computer technology',
#    'construction',
#    'education',
#    'food restaurant',
#    'healthcare',
#    'hotel hospitality',
#    'installation repair',
#    'law enforcement security',
#    'personal care',
#    'sales marketing',
#    'services',
#    'transportation',
#    'warehouse production',
#    'wellness'],
#   'ghost-rider': ['animal care',
#    'auto maintenance',
#    'carpentry',
#    'casino',
#    'catering',
#    'childcare',
#    'customer service',
#    'data analyst',
#    'education',
#    'electrical',
#    'engineering',
#    'financial',
#    'food and beverage',
#    'health and wellness',
#    'hotel',
#    'it',
#    'landscaping',
#    'legal',
#    'management',
#    'music',
#    'sales',
#    'security',
#    'technician',
#    'trade vocation',
#    'transportation',
#    'warehouse'],
#   'johnmoon': ['automotive',
#    'banking',
#    'beauty and spa',
#    'child care',
#    'commercial driver',
#    'construction',
#    'finance',
#    'food service',
#    'heathcare',
#    'hospitality',
#    'housekeeping',
#    'human resources',
#    'manufacturing',
#    'marketing',
#    'mechanical engineer',
#    'retail',
#    'security',
#    'software engineer',
#    'teaching',
#    'veterinary',
#    'warehouse worker'],
#   'rmealey': ['admin and paraprofessional',
#    'automotive services and maintenance',
#    'childcare and early education',
#    'environmental services',
#    'event services',
#    'food and beverage',
#    'gaming and casinos',
#    'health and wellness direct care',
#    'health and wellness professional',
#    'health and wellness technician',
#    'home renovation contracting services',
#    'hospitality',
#    'industrial manufacturing trades',
#    'personal services and instruction',
#    'pet services',
#    'professional',
#    'retail',
#    'security services',
#    'trucking and transportation']}}

# %%
posting_labels = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: list())))
for d in user_labels.keys():
    ntopics = d.split("/")[1].split("_")[-1]
    for user in user_labels[d].keys():
        if user_labels[d][user]["IsFinal"]: 
            for label in user_labels[d][user]["All classification results:"]:
                posting_labels[label["posting_id"]][user][ntopics] += [label["label"],]
    else:
        for label in user_labels[d][user]["User labels:"]:
            posting_labels[label["posting_id"]][user][ntopics] += [label["label"],]

len(posting_labels.keys())
posting_labels = {pid:{user:{ntopics:l for ntopics,l in labels.items()} for user, labels in user_labels.items()} for pid, user_labels in posting_labels.items()}
posting_labels
# Out:
# {'37958256': {'jason.kowalewski@snagajob.com': {'40': ['tutoring']},
#   'rmealey2': {'20': ['personal services and instruction']}},
#  '37958013': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '44099820': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '30523041': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '43735830': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '34489524': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44201834': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '28728638': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '41734445': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['animal services']},
#   'rmealey2': {'20': ['direct sales and marketing']}},
#  '35432048': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44201830': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '43753381': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '38320047': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '35357974': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['clerical']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '40079724': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'jason.kowalewski@snagajob.com': {'40': ['security']},
#   'rmealey2': {'20': ['security services']}},
#  '26171727': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '26787306': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '29732788': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'johnmoon': {'20': ['food service']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '42406321': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '40167107': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '33827309': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '39473076': {'Jonathan Daberkow': {'20': ['hospitality']},
#   'johnmoon': {'20': ['hospitality']},
#   'rmealey2': {'20': ['hospitality']}},
#  '43649269': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '36405545': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '38281701': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '42660885': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '37901251': {'jason.kowalewski@snagajob.com': {'40': ['tutoring']},
#   'rmealey2': {'20': ['personal services and instruction']}},
#  '33873308': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '26787314': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '35904342': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '38320177': {'johnmoon': {'20': ['education']},
#   'rmealey2': {'20': ['personal services and instruction']}},
#  '26226984': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '44088815': {'Jonathan Daberkow': {'20': ['customer service']},
#   'jason.kowalewski@snagajob.com': {'40': ['customer support']},
#   'johnmoon': {'20': ['sales and support']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '42581633': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '29421368': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '30517739': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '30517732': {'rmealey2': {'20': ['admin and paraprofessional']}},
#  '42581639': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '26810996': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '35781417': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '43329103': {'rmealey2': {'20': ['food and beverage']}},
#  '34392076': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '33584131': {'Jonathan Daberkow': {'20': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '35742254': {'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '40073045': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['finance']},
#   'rmealey2': {'20': ['professional']}},
#  '26544472': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '28670342': {'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '44385973': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '35652491': {'rmealey2': {'20': ['admin and paraprofessional']}},
#  '39761182': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '29477296': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '36014137': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '30604230': {'Jonathan Daberkow': {'20': ['engineering']},
#   'johnmoon': {'20': ['construction']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '38769251': {'johnmoon': {'20': ['manufacturing']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '30778239': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness direct care']}},
#  '41904583': {'Jonathan Daberkow': {'20': ['software engineering']},
#   'jason.kowalewski@snagajob.com': {'40': ['computers and software']},
#   'johnmoon': {'20': ['software engineering', 'software engineer']},
#   'rmealey2': {'20': ['professional']}},
#  '42844871': {'johnmoon': {'20': ['construction']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '44031903': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'jason.kowalewski@snagajob.com': {'40': ['security']},
#   'johnmoon': {'20': ['security']},
#   'rmealey2': {'20': ['security services']}},
#  '30405916': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '36496456': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '42936819': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '30586624': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '39398861': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '33485524': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '39431310': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '34028438': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'johnmoon': {'20': ['security']},
#   'rmealey2': {'20': ['security services']}},
#  '44151027': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '30523036': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '44426389': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '30651014': {'rmealey2': {'20': ['retail']}},
#  '43961310': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '36002289': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '40889361': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '36276169': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '43970378': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '44344137': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['clerical']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '28981722': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '44005305': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '39891975': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '41365116': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '43733454': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '38598539': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '39080505': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'johnmoon': {'20': ['trucking and transportation']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '43534132': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '44425189': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43572127': {'johnmoon': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '39261722': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness technician']}},
#  '44504017': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '44139290': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'johnmoon': {'20': ['child care']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '30778010': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness direct care']}},
#  '30778253': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness direct care']}},
#  '44502194': {'Jonathan Daberkow': {'20': ['software engineering']},
#   'jason.kowalewski@snagajob.com': {'40': ['computers and software']},
#   'johnmoon': {'20': ['software engineering', 'software engineer']},
#   'rmealey2': {'20': ['professional']}},
#  '43788214': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '41035875': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '35774079': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '36405626': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '39305855': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness direct care']}},
#  '30020100': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness technician']}},
#  '33812097': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '44430522': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '36580679': {'Jonathan Daberkow': {'20': ['retail']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '35934177': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '43534363': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '40833471': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43533277': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '43647167': {'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '42581672': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['clerical']},
#   'rmealey2': {'20': ['professional']}},
#  '36077604': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'rmealey2': {'20': ['security services']}},
#  '40709805': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '42637732': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '42967167': {'rmealey2': {'20': ['admin and paraprofessional']}},
#  '34245438': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'rmealey2': {'20': ['security services']}},
#  '40609285': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '40609167': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '44052511': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '43534471': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '43790424': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '40209252': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '25717803': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness technician']}},
#  '39203335': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '35714501': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '37591344': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '42770173': {'Jonathan Daberkow': {'20': ['construction']},
#   'johnmoon': {'20': ['construction']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '37592792': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '44504153': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '28862219': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '44031939': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'rmealey2': {'20': ['security services']}},
#  '29004286': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness technician']}},
#  '38598622': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '36405725': {'Jonathan Daberkow': {'20': ['petcare']},
#   'rmealey2': {'20': ['pet services']}},
#  '34522608': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'rmealey2': {'20': ['security services']}},
#  '40167101': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '34287941': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '40609290': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '44220682': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '40209487': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'johnmoon': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '41116223': {'rmealey2': {'20': ['hospitality']}},
#  '38598503': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '38301812': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '40867558': {'Jonathan Daberkow': {'20': ['real estate']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '29620408': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '39473009': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '42641099': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '40709825': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '40709824': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '36076735': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '40709826': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '41036639': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '26942057': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '35718098': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '29007664': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '40785664': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44297260': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '44440140': {'Jonathan Daberkow': {'20': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '43050502': {'rmealey2': {'20': ['professional']}},
#  '40785658': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '42339123': {'johnmoon': {'20': ['child care']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '30604656': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '36273867': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '37900667': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '42480886': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '43003624': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '36169199': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '40471881': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43003622': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '44373323': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '40852574': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '39080898': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '37091369': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '41712127': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness direct care']}},
#  '35911154': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'johnmoon': {'20': ['child care']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '40166550': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '41845913': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '34204535': {'rmealey2': {'20': ['admin and paraprofessional']}},
#  '40816262': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '39082719': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '39747477': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '36589054': {'jason.kowalewski@snagajob.com': {'40': ['tutoring']},
#   'jmexp1': {'80': ['education professional']},
#   'rmealey2': {'20': ['personal services and instruction']}},
#  '37902978': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '39990457': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '30779271': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '30604647': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '43315231': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '39526651': {'johnmoon': {'20': ['finance']},
#   'rmealey2': {'20': ['professional']}},
#  '43313055': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']},
#   'johnmoon': {'20': ['software engineering', 'software engineer']},
#   'rmealey2': {'20': ['professional']}},
#  '28745133': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '43225333': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'johnmoon': {'20': ['manufacturing']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '43971406': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '40108435': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43971400': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '36352644': {'Jonathan Daberkow': {'20': ['petcare']},
#   'rmealey2': {'20': ['pet services']}},
#  '43971402': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '33307558': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '37911787': {'Jonathan Daberkow': {'20': ['petcare']},
#   'rmealey2': {'20': ['pet services']}},
#  '39080686': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '37101607': {'Jonathan Daberkow': {'20': ['education']},
#   'jason.kowalewski@snagajob.com': {'40': ['tutoring']},
#   'rmealey2': {'20': ['personal services and instruction']}},
#  '33048168': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '40902591': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'jason.kowalewski@snagajob.com': {'40': ['aviation technicians']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '35716843': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '44422968': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '34252720': {'Jonathan Daberkow': {'20': ['retail']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['retail']}},
#  '36274933': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '29477218': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '35849017': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['retail']},
#   'rmealey2': {'20': ['professional']}},
#  '36013689': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '41689851': {'Jonathan Daberkow': {'20': ['software engineering']},
#   'jason.kowalewski@snagajob.com': {'40': ['computers and software']},
#   'johnmoon': {'20': ['software engineering']},
#   'rmealey2': {'20': ['professional']}},
#  '38196787': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['clerical']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '43655420': {'Jonathan Daberkow': {'20': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '39080797': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '39597969': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'rmealey2': {'20': ['security services']}},
#  '41037131': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '34092189': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '35226681': {'Jonathan Daberkow': {'20': ['childcare']},
#   'johnmoon': {'20': ['child care']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '36002570': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '30781496': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '38261975': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '29620320': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '39081798': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '44110623': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '35865757': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '34252708': {'Jonathan Daberkow': {'20': ['retail']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'johnmoon': {'20': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '39735469': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '40435617': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '44337166': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43518960': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['retail']},
#   'rmealey2': {'20': ['professional']}},
#  '38317513': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '40435621': {'rmealey2': {'20': ['health and wellness professional']}},
#  '37153460': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '37903978': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '43560779': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44223551': {'Jonathan Daberkow': {'20': ['childcare']},
#   'johnmoon': {'20': ['child care']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '29175033': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '35761663': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '43401711': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '35714204': {'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '43933591': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44010179': {'johnmoon': {'20': ['sales and support']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '42372135': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '31170817': {'johnmoon': {'20': ['food service']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '36278036': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '40198101': {'Jonathan Daberkow': {'20': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '34387417': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '27444363': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '44373762': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44512384': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '44512385': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '44351870': {'Jonathan Daberkow': {'20': ['hospitality']},
#   'rmealey2': {'20': ['hospitality']}},
#  '35713218': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '44512382': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '43089285': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '38965246': {'rmealey2': {'20': ['retail']}},
#  '42479995': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'rmealey2': {'20': ['security services']}},
#  '33994728': {'Jonathan Daberkow': {'20': ['retail']},
#   'jmexp1': {'80': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '29993868': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '44142985': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '35713223': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '34250513': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['direct sales and marketing']}},
#  '38199602': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '38282509': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '29738995': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness technician']}},
#  '33762753': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '36466250': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '30736391': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness direct care']}},
#  '44202504': {'Jonathan Daberkow': {'20': ['hospitality']},
#   'rmealey2': {'20': ['hospitality']}},
#  '33762759': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '35761641': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '42199501': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'johnmoon': {'20': ['child care']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '40435405': {'Jonathan Daberkow': {'20': ['engineering']},
#   'johnmoon': {'20': ['construction']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '39366913': {'Jonathan Daberkow': {'20': ['facility maintenance']},
#   'jason.kowalewski@snagajob.com': {'40': ['manufacturing']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '29174048': {'johnmoon': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness technician']}},
#  '40435402': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '36014334': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '36875669': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '43743086': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '34518509': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '41285901': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'johnmoon': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '35781345': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '42475174': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'rmealey2': {'20': ['security services']}},
#  '39134906': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '43364610': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['clerical']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '40435410': {'Jonathan Daberkow': {'20': ['engineering']},
#   'johnmoon': {'20': ['construction']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '42805376': {'jason.kowalewski@snagajob.com': {'40': ['customer support']},
#   'johnmoon': {'20': ['call center']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '42688786': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '42687696': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44434991': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '42480873': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '42480994': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['professional']}},
#  '36226502': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '36278260': {'Jonathan Daberkow': {'20': ['general contracting']},
#   'jason.kowalewski@snagajob.com': {'40': ['construction']},
#   'rmealey2': {'20': ['home contracting renovation repair']}},
#  '30337671': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '39081237': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '35828492': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '39531849': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '41866683': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '28273259': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '40281704': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '29659988': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '43278256': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['direct sales and marketing']}},
#  '43409916': {'rmealey2': {'20': ['hospitality']}},
#  '35820890': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '38081825': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jason.kowalewski@snagajob.com': {'40': ['catering']},
#   'rmealey2': {'20': ['event services']}},
#  '41262716': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '42520902': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '44511017': {'Jonathan Daberkow': {'20': ['retail']},
#   'johnmoon': {'20': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '38342873': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '38972642': {'Jonathan Daberkow': {'20': ['business administration']},
#   'johnmoon': {'20': ['clerical']},
#   'rmealey2': {'20': ['professional']}},
#  '44089338': {'rmealey2': {'20': ['admin and paraprofessional']}},
#  '39399190': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '39399174': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '36640584': {'jason.kowalewski@snagajob.com': {'40': ['tutoring']},
#   'rmealey2': {'20': ['personal services and instruction']}},
#  '38693180': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '38963940': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '43338405': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '39176859': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '43313454': {'johnmoon': {'20': ['finance']},
#   'rmealey2': {'20': ['professional']}},
#  '39987442': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'jason.kowalewski@snagajob.com': {'40': ['security']},
#   'johnmoon': {'20': ['security']},
#   'rmealey2': {'20': ['security services']}},
#  '36437833': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'jmexp1': {'80': ['food service serving']},
#   'johnmoon': {'20': ['food service']},
#   'rmealey2': {'20': ['event services']}},
#  '40435398': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '40818725': {'Jonathan Daberkow': {'20': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '37153650': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '44202142': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness direct care']}},
#  '34458580': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '42474812': {'Jonathan Daberkow': {'20': ['police fire ems']},
#   'jason.kowalewski@snagajob.com': {'40': ['security']},
#   'rmealey2': {'20': ['security services']}},
#  '33441373': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '44499038': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '39399062': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '27143361': {'Jonathan Daberkow': {'20': ['business administration']},
#   'rmealey2': {'20': ['admin and paraprofessional']}},
#  '38274882': {'rmealey2': {'20': ['personal services and instruction']}},
#  '30580413': {'Jonathan Daberkow': {'20': ['truck driving']},
#   'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'rmealey2': {'20': ['trucking and transportation']}},
#  '42665645': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43108632': {'Jonathan Daberkow': {'20': ['engineering']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing professional']}},
#  '36677760': {'Jonathan Daberkow': {'20': ['food and restaurant']},
#   'rmealey2': {'20': ['food and beverage']}},
#  '41037080': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43237916': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '39826584': {'Jonathan Daberkow': {'20': ['warehouse and production']},
#   'rmealey2': {'20': ['warehouse industrial manufacturing trades']}},
#  '34529610': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '43854300': {'Jonathan Daberkow': {'20': ['childcare']},
#   'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'rmealey2': {'20': ['childcare and early education']}},
#  '26442912': {'Jonathan Daberkow': {'20': ['healthcare']},
#   'rmealey2': {'20': ['health and wellness professional']}},
#  '44399430': {'Jonathan Daberkow': {'20': ['retail']},
#   'rmealey2': {'20': ['retail']}},
#  '29738561': {'Jonathan Daberkow': {'20': ['healthcare']},
# ...
#  '41657916': {'jason.kowalewski@snagajob.com': {'40': ['retail']},
#   'johnmoon': {'20': ['retail']}},
#  '41759271': {'jason.kowalewski@snagajob.com': {'40': ['childcare']},
#   'johnmoon': {'20': ['child care']}},
#  '41904621': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']},
#   'johnmoon': {'20': ['software engineer']}},
#  '42287162': {'johnmoon': {'20': ['commercial driver']}},
#  '42293122': {'johnmoon': {'20': ['hospitality']}},
#  '42668523': {'johnmoon': {'20': ['software engineer']}},
#  '43036494': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']},
#   'johnmoon': {'20': ['software engineer']}},
#  '43068092': {'johnmoon': {'20': ['hospitality']}},
#  '43370306': {'johnmoon': {'20': ['software engineer']}},
#  '43565410': {'johnmoon': {'20': ['construction']}},
#  '43593282': {'johnmoon': {'20': ['construction']}},
#  '43646919': {'johnmoon': {'20': ['software engineer']}},
#  '43873331': {'johnmoon': {'20': ['heathcare']}},
#  '44195724': {'jason.kowalewski@snagajob.com': {'40': ['food and restaurant']},
#   'johnmoon': {'20': ['hospitality']}},
#  '44302301': {'johnmoon': {'20': ['software engineer']}},
#  '44391712': {'johnmoon': {'20': ['software engineer']}},
#  '44512949': {'johnmoon': {'20': ['commercial driver']}},
#  '40833549': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '33910706': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '35814529': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '34204709': {'jason.kowalewski@snagajob.com': {'40': ['engineering']}},
#  '37903780': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '29494855': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '42063689': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '35617108': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '43744307': {'jason.kowalewski@snagajob.com': {'40': ['hospitality']}},
#  '44247711': {'jason.kowalewski@snagajob.com': {'40': ['finance']}},
#  '36198009': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '37903788': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '40136602': {'jason.kowalewski@snagajob.com': {'40': ['food and restaurant']}},
#  '39263940': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44247713': {'jason.kowalewski@snagajob.com': {'40': ['finance']}},
#  '37901118': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '33620206': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '42635340': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '43719358': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '43721670': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41811171': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '41665345': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41357888': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '28478953': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '44438466': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43594128': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '41868057': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44496330': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '40284524': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '43095917': {'jason.kowalewski@snagajob.com': {'40': ['engineering']}},
#  '30298429': {'jason.kowalewski@snagajob.com': {'40': ['food and restaurant']}},
#  '42889639': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43719364': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '44475408': {'jason.kowalewski@snagajob.com': {'40': ['retail']}},
#  '35192053': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '42008839': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '29494843': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '44349728': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '44438456': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '44026341': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36019830': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '43693093': {'jason.kowalewski@snagajob.com': {'40': ['finance']}},
#  '43693092': {'jason.kowalewski@snagajob.com': {'40': ['legal']}},
#  '40249310': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '41355214': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '39135646': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36443608': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '39122326': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36277368': {'jason.kowalewski@snagajob.com': {'40': ['catering']}},
#  '41434593': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '37214437': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38046293': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38278311': {'jason.kowalewski@snagajob.com': {'40': ['tutoring']}},
#  '33869167': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '37903776': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '38335439': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43272057': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43927434': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '43260009': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43169003': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44089928': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '39122339': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '42469931': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '37022429': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '43971588': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']},
#   'jmexp1': {'80': ['hospitality housekeeping']}},
#  '44300475': {'jason.kowalewski@snagajob.com': {'40': ['skilled manufacturing']}},
#  '42783269': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '44345345': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43970258': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '42942380': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '26948955': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '37902490': {'jason.kowalewski@snagajob.com': {'40': ['tutoring']}},
#  '44430533': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '39266176': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '37293256': {'jason.kowalewski@snagajob.com': {'40': ['legal']}},
#  '38692719': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '29262776': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '32754863': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '41587324': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '39241719': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41590969': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '40209270': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '35904536': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '43693067': {'jason.kowalewski@snagajob.com': {'40': ['legal']}},
#  '37914489': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38335458': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41327192': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '33655744': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '42340814': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '43350036': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '29728361': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '34935868': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '41567721': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '34909564': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '37458543': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43537506': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41721102': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '28953138': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '44139068': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '42930368': {'jason.kowalewski@snagajob.com': {'40': ['skilled manufacturing']}},
#  '30616659': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38812280': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43276446': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '43095908': {'jason.kowalewski@snagajob.com': {'40': ['legal']}},
#  '44009805': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '40925357': {'jason.kowalewski@snagajob.com': {'40': ['skilled manufacturing']}},
#  '43990713': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '44060255': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '29409328': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '44475416': {'jason.kowalewski@snagajob.com': {'40': ['retail']}},
#  '42245401': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44145747': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '26579168': {'jason.kowalewski@snagajob.com': {'40': ['food and restaurant']}},
#  '39070607': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '43990711': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '40357172': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '37100425': {'jason.kowalewski@snagajob.com': {'40': ['retail']}},
#  '39080872': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38784531': {'jason.kowalewski@snagajob.com': {'40': ['marketing']}},
#  '26437916': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '38792158': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44369343': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '40249345': {'jason.kowalewski@snagajob.com': {'40': ['finance']}},
#  '39464892': {'jason.kowalewski@snagajob.com': {'40': ['food and restaurant']}},
#  '43402681': {'jason.kowalewski@snagajob.com': {'40': ['hospitality']}},
#  '35004955': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '40074690': {'jason.kowalewski@snagajob.com': {'40': ['legal']}},
#  '43534467': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '27778143': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36011913': {'jason.kowalewski@snagajob.com': {'40': ['education']}},
#  '34909586': {'jason.kowalewski@snagajob.com': {'40': ['food and restaurant']}},
#  '43172684': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44409062': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '43720373': {'jason.kowalewski@snagajob.com': {'40': ['skilled manufacturing']}},
#  '33047559': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '39189405': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '39369492': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '44138558': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '34051403': {'jason.kowalewski@snagajob.com': {'40': ['warehouse']}},
#  '36832209': {'jason.kowalewski@snagajob.com': {'40': ['finance']}},
#  '43166817': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '43352664': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43780009': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44409059': {'jason.kowalewski@snagajob.com': {'40': ['skilled manufacturing']}},
#  '44512074': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '39082607': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '40074682': {'jason.kowalewski@snagajob.com': {'40': ['legal']}},
#  '34443123': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43743067': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '30604657': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43532705': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36676127': {'jason.kowalewski@snagajob.com': {'40': ['aviation technicians']}},
#  '25793297': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '30585013': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36033274': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '25594019': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '44074807': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '34861016': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '36726962': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '41233680': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36095538': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '38435681': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '35579154': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '33928881': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '43281829': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38725359': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38965047': {'jason.kowalewski@snagajob.com': {'40': ['customer support']}},
#  '39152107': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '41118661': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43933287': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '35681757': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '44503112': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '39153432': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '32577902': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '39082624': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41757180': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '42063625': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '40573762': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '43580371': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43580370': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43945239': {'jason.kowalewski@snagajob.com': {'40': ['security']}},
#  '34275097': {'jason.kowalewski@snagajob.com': {'40': ['skilled manufacturing']}},
#  '33559019': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '35714300': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '44503149': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '30604637': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '32808316': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '36004734': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '41574812': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41819993': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '34387319': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '41499040': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43679632': {'jason.kowalewski@snagajob.com': {'40': ['manufacturing']}},
#  '35384057': {'jason.kowalewski@snagajob.com': {'40': ['childcare']}},
#  '40198007': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '43352677': {'jason.kowalewski@snagajob.com': {'40': ['computers and software']}},
#  '42366609': {'jason.kowalewski@snagajob.com': {'40': ['skilled manufacturing']}},
#  '35864874': {'jason.kowalewski@snagajob.com': {'40': ['construction']}},
#  '39082612': {'jason.kowalewski@snagajob.com': {'40': ['healthcare']}},
#  '38277066': {'jason.kowalewski@snagajob.com': {'40': ['catering']}},
#  ...}
